# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
data = pd.read_json('reviewSelected100.json',lines=True, 
                    orient='records',encoding = "ISO-8859-1")

# %%
display(data)
# Out:
#                     review_id                 user_id             business_id  \
# 0      8aoJJdKEO3ypoZNszpPu7Q  bGgAL09pxLnV_FFgR4ZADg  ZBE-H_aUlicix_9vUGQPIQ
# 1      J5NOCLdhuhor7USRhtYZ8w  pFCb-1j6oI3TDjr26h2cJQ  e-YnECeZNt8ngm0tu4X9mQ
# 2      PXiLWAYRt3xnHaJ8MB4rzw  mEzc6LeTNiQgIVsq3poMbg  j7HO1YeMQGYo3KibMXZ5vg
# 3      VrLarvxZYJm74yAqtpe9PQ  o-zUN2WEZgjQS7jnNsec0g  7e3PZzUpG5FYOTGt3O3ePA
# 4      C1CUpidlVFprUCkApqzCmA  Wlx0iBXJvk4x0EeOt2Bz1Q  vuHzLZ7nAeT-EiecOkS5Og
# ...                       ...                     ...                     ...
# 15295  qknwFVEh_0KSuexigYBI_A  YMGmyPOU65SMs4H60ltYiw  shIPnFoXrL3dFo5HLH1_HA
# 15296  Y-ZRoyAXCukBK1uK1ZcZCA  JLhOWQiWtGbr14K_KmoWxA  zPEYgVqJ2QNKi45FJi2jvg
# 15297  A8HdjBfhj3pgQuSbwNtDEw  6CoiKFDFXIACJZvv_I_8mQ  zPEYgVqJ2QNKi45FJi2jvg
# 15298  2n1QdrYBRAAe6GKaxEV0jA  _fH4s3ls08eSl_PfX38KIA  etzDsNjkCyQBoJcU2a3U-g
# 15299  4B9k5hmmLWV_lhIYvVcPWA  msRUiBE7Sa5A9145ZdFBow  9Xm2GfG8Rnbb1_CmXyrm3g
#
#        stars  useful  funny  cool  \
# 0          5       0      0     0
# 1          4       0      0     0
# 2          5       2      1     3
# 3          3       0      0     0
# 4          1      11      0     3
# ...      ...     ...    ...   ...
# 15295      1       2      0     0
# 15296      5       0      0     0
# 15297      1       0      1     0
# 15298      5       0      0     0
# 15299      5       0      0     0
#
#                                                     text                date
# 0      We had my Mother's Birthday Party here on 10/2... 2016-11-09 20:07:25
# 1      Good Korean grill near Eaton Centre. The marin... 2015-12-05 05:06:43
# 2      Was recommended to try this place by few peopl... 2014-10-11 05:16:15
# 3      Ambience: Would not expect something this nice... 2016-07-25 03:45:26
# 4      Absolutely the WORST pool company that I have ... 2016-04-11 18:49:11
# ...                                                  ...                 ...
# 15295  This was the worst experience ever. So much so... 2014-07-12 21:58:15
# 15296  We come here every time we hit Vegas! A giant ... 2018-11-10 21:38:49
# 15297  As locals we used  to the this place when it w... 2018-10-13 22:11:22
# 15298  The food was delicious. We were seated in 15 m... 2015-02-15 08:43:46
# 15299  Wonderful spot (the patio) and OH SO EXCELLENT... 2018-10-06 19:00:13
#
# [15300 rows x 9 columns]

# %% [markdown]
# #### Randomly select 50 reviews from different businesses with rating 1

# %%
#uniqueBusiness = data['business_id'].unique()
#uniqueBusiness.size

# %%
# Filter reviews with 1 star and store in a dataframe
oneStar = data[data['stars']==1]

# %%
# Group by business ID and sample a random 1-star review from each group (1 per business)
grouped = oneStar.groupby('business_id').sample(n=1)
len(grouped)
# Out:
# 150

# %%
# Randomly select 50 reviews of rating 1 (one from each business)
random50 = grouped.sample(n=50)
#len(random50)
display(random50)
# Out:
#                     review_id                 user_id             business_id  \
# 4322   lphu4xoFSxe_md-UDxxDMQ  frrRxKs3ZNXU6aOSMO56fg  NRAmrbIGgXgH5uYv8GGJ5A
# 9169   fjbdEEvyV0Ai__iorDVvRQ  Kc3lfU85nH3wLhHliESL4A  dhBAQJLKPCI7nm3x0WjXTw
# 8191   -OSCqWUWr7PuehB6aZo81A  D7cHJq2uldNtWY7bDfInzw  mF2EW3twSrFPmT_RVV1-Qg
# 9710   RciGGpo9dD521IVMez_D2A  YilGjn9j1muEUgJhSmMCMg  GUsYtGG557XKlHaMH87erg
# 8636   v5eaDKr68bkzapP3Ko_vlQ  Hib9a-z64xIoAsZC4uarFA  TrwniH-1-Jo_MNNDW2zMkA
# 12588  TeoRPZ_4P27Qz4SA5ZbnvQ  fNwi7dQfltSQDfbJXoKupQ  QaFO4S6HFUu2NIbeu4OwCg
# 12074  Knj-Zfr3EX_apVzUzvByeQ  vHPHH6QJaXRWiPgvT-6BsQ  QqGMtc24VdCzYAajw1g4bA
# 310    LbWeedxFTVhwtrOQ5N1nWQ  wnFWoQ63F9-ohUQ-C0AeIw  ZBE-H_aUlicix_9vUGQPIQ
# 75     d7AbTtm-R3RO6YdOQqen1w  cSBOGzMawtoIGYUPQePy8g  wPgp3oddFUzpGrQc__HYhg
# 9993   cIKYi9JJnGPaMj4Qf05HnA  rn2DB_YX0BvToYe50RNr_Q  AktuBx1W7c3ZdzwuaOp8xg
# 1169   us4JIlQsNk20ER6jLoM13A  uCRHROUN201UsgjnZaIYfg  --I7YYLada0tSLkORTHb5Q
# 12777  oRoAcYVWvciPVZ9hUK0lTg  hdcz_pNTnMCN9yQKhoJoIw  IzcL0KZPKqMbjoIaCmClog
# 10515  t8jGsWXuFt0NQGNtAqzUQg  tMbNBTPLlx3UQMY2Zc8_7A  QxRKQ_Lzu4lMOejwVgcdAg
# 1177   B2oVxI3t1ss5-SAT60mheQ  1rvVoZP1iwwoJ4T-ZYjmYA  e-YnECeZNt8ngm0tu4X9mQ
# 15182  IMkZGwRsyze2Qu9YeO69Qw  -u6pCmwYoakDJ9KeeAGo4A  zPEYgVqJ2QNKi45FJi2jvg
# 12849  o5WVZlWXPySY3y7S7gs8Jw  lZrWuyTcxky-R9PjmNBxzw  xvjkhS2PXajDniDzP1-hdA
# 8360   lIJawZdbp2gF0GGFlUW1rg  dLsfhUFyh4W8X-2u-pTcHQ  XVDR44P_74FmA0ANanm4CQ
# 10832  pwYDIrUD6dyoR6XTb_VxXw  gVF4bL8vlJVPPTP4WbS7qQ  ZP7U4qUCMjIvasWV7a_mgg
# 3564   kSSdgkTE0OyUJqF4aqR-dw  bc1haNiFt92mglxx6ejWvQ  mOzOYgXYOmkdNfZr453PgQ
# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
noun_adj_pairs = []

for i in random50['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((token,doc[j]))
              break
noun_adj_pairs
# Out:
# [(go, several),
#  (place, several),
#  (months, new),
#  (manager, interested),
#  (restaurant, last),
#  (Today, last),
#  (straw, same),
#  (manager, more),
#  (minutes, obvious),
#  (server, obvious),
#  (manager, obvious),
#  (breeze, obvious),
#  (buddies, horrible),
#  (Sad, horrible),
#  (atmosphere, horrible),
#  (manager, happy),
#  (WARNING, little),
#  (poke, little),
#  (Seoul, little),
#  (Poke, little),
#  (Bowl, little),
#  (Umami, amazing),
#  (Pokerito, amazing),
#  (Pineville, amazing),
#  (place, bad),
#  (stars, tiny),
#  (ass, mushy),
#  (bowl, mushy),
#  (rice, mediocre),
#  (fish, large),
#  (pics, large),
#  (place, large),
#  (lbs, large),
#  (poke, salty),
#  (bowl, salty),
#  (restaurant, salty),
#  (feeling, salty),
#  (poke, salty),
#  (nachos, salty),
#  (heart, salty),
#  (kidney, salty),
#  (failure, salty),
#  (sodium, salty),
#  (overdose, salty),
#  (dish, salty),
#  (chips, salty),
#  (sauce, unhealthy),
#  (fish, unhealthy),
#  (smell, fresh),
#  (fish, fresh),
#  (Idk, bad),
#  (waiters, salty),
#  (one, EXACT),
#  (thing, terrible),
#  (Anyways, terrible),
#  (conclusion, terrible),
#  (place, terrible),
#  (lol, most),
#  (people, overpriced),
#  (concept, overpriced),
#  (Poke, overpriced),
#  (tasting, more),
#  (food, more),
#  (places, more),
#  (Manhattan, more),
#  (way, more),
#  (food, fresh),
#  (House, horrible),
#  (Hunan, horrible),
#  (Medina, horrible),
#  (dinner, horrible),
#  (experience, wobbly),
#  (table, wobbly),
#  (dining, sweet),
#  (experience, sweet),
#  (wife, sweet),
#  (shrimp, Most),
#  (item, cold),
#  (shrimp, cold),
#  (vegetables, green),
#  (peppers, cold),
#  (thing, good),
#  (dish, bad),
#  (sauce, bad),
#  (one, bad),
#  (food, ok),
#  (heck, ok),
#  (dish, ok),
#  (tso, better),
#  (chicken, better),
#  (food, poor),
#  (waitress, poor),
#  (chips, OK),
#  (margarita, OK),
#  (service, short),
#  (breakfast, short),
#  (burrito, short),
#  (fuse, friendly),
#  (tude, friendly),
#  (lady, friendly),
#  (Yolanda, friendly),
#  (man, hungry),
#  (beers, hungry),
#  (morning, hungry),
#  (becos, hungry),
#  (fact, hungry),
#  (words, good),
#  (customers, good),
#  (livelihood, good),
#  (burrito, good),
#  (cook, friendly),
#  (face, shy),
#  (Yolanda, shy),
#  (vehicle, rude),
#  (type, rude),
#  (service, rude),
#  (customer, rude),
#  (service, rude),
#  (service, rude),
#  (advisor, rude),
#  (cashier, rude),
#  (name, rude),
#  (tag, rude),
#  (customers, convenient),
#  (area, convenient),
#  (place, convenient),
#  (vehicle, convenient),
#  (appt, convenient),
#  (coupons, sorry),
#  (mins, sorry),
#  (line, sorry),
#  (turn, sorry),
#  (u, sorry),
#  (appointment, sorry),
#  (diagnostic, sorry),
#  (hours, sorry),
#  (oil, other),
#  (change, other),
#  (today, other),
#  (oil, other),
#  (change, other),
#  (today, other),
#  (front, other),
#  (customers, vague),
#  (appt, vague),
#  (system, vague),
#  (appointment, vague),
#  (system, vague),
#  (car, professional),
#  (customers, rude),
#  (business, rude),
#  (people, rude),
#  (line, rude),
#  (guy, aware),
#  (GM, aware),
#  (company, aware),
#  (indicator, most),
#  (reviews, fake),
#  (star, fake),
#  (stars, fake),
#  (experience, blatant),
#  (people, blatant),
#  (car, blatant),
#  (dealers, blatant),
#  (advertisement, undeniable),
#  (lie, shady),
#  (Chapman, new),
#  (Mazda, new),
#  (car, new),
#  (oil, new),
#  (change, new),
#  (life, new),
#  (vehicle, new),
#  (card, new),
#  (life, new),
#  (vehicle, new),
#  (years, new),
#  (offer, new),
#  (explanation, new),
#  (offer, new),
#  (offer, new),
#  (buyers, dishonest),
#  (people, dishonest),
#  (life, dishonest),
#  (vehicle, dishonest),
#  (offer, dishonest),
#  (service, less),
#  (manager, less),
#  (phone, less),
#  (oil, less),
#  (change, less),
#  (price, less),
#  (oil, less),
#  (change, less),
#  (LIE, dishonest),
#  (people, dishonest),
#  (couple, extra),
#  (Polly, best),
#  (look, best),
#  (way, sure),
#  (tip, sure),
#  (Haters, little),
#  (lunch, first),
#  (manager, first),
#  (sound, first),
#  (game, first),
#  (NHL, first),
#  (problem, first),
#  (sound, first),
#  (game, first),
#  (buddies, first),
#  (mind, first),
#  (sound, first),
#  (server, first),
#  (music, first),
#  (playing, first),
#  (problem, first),
#  (beer, polite),
#  (order, polite),
#  (manager, polite),
#  (beers, polite),
#  (person, more),
#  (game, more),
#  (sound, more),
#  (sound, more),
#  (game, more),
#  (server, more),
#  (time, ridiculous),
#  (round, ridiculous),
#  (sound, ridiculous),
#  (beers, ridiculous),
#  (server, ridiculous),
#  (manager, ridiculous),
#  (cash, ridiculous),
#  (table, ridiculous),
#  (check, ridiculous),
#  (sound, ridiculous),
#  (hour, busy),
#  (half, busy),
#  (food, busy),
#  (minutes, attentive),
#  (avacado, attentive),
#  (burger, attentive),
#  (servers, attentive),
#  (owners, smaller),
#  (picture, smaller),
#  (wall, smaller),
#  (left, smaller),
#  (portions, smaller),
#  (service, slower),
#  (means, close),
#  (Shrimp, close),
#  (Pad, close),
#  (Thai, close),
#  (booths, happy),
#  (patrons, happy),
#  (hand, happy),
#  (sign, happy),
#  (walls, happy),
#  (plates, happy),
#  (people, unfriendly),
#  (place, unfriendly),
#  (business, unfriendly),
#  (sign, unfriendly),
#  (seconds, cheap),
#  (persons, cheap),
#  (plates, cheap),
#  (plates, cheap),
#  (dollar, low),
#  (store, low),
#  (styrofoam, low),
#  (plates, low),
#  (budget, low),
#  (quality, good),
#  (husband, wonderful),
#  (yesterday, wonderful),
#  (fish, limp),
#  (sandwich, limp),
#  (fries, limp),
#  (sandwich, limp),
#  (greasy, hard),
#  (fries, frozen),
#  (fish, frozen),
#  (fish, large),
#  (stick, large),
#  (chicken, yummy),
#  (McNugget, yummy),
#  (baguette, bland),
#  (Catawba, only),
#  (sauce, only),
#  (mayo, only),
#  (siracha, only),
#  (tasting, good),
#  (thing, good),
#  (fish, good),
#  (sandwich, good),
#  (fish, good),
#  (McNugget, good),
#  (sandwiches, good),
#  (fish, good),
#  (sandwiches, good),
#  (fries, good),
#  (home, good),
#  (beer, good),
#  (husband, good),
#  (drinking, good),
#  (water, good),
#  (pickles, good),
#  (breading, Overall),
#  (food, worth),
#  (range, nice),
#  (employees, nice),
#  (ASS, BOLD),
#  (GUY, Young),
#  (GLASSES, Young),
#  (friends, Young),
#  (range, Young),
#  (rule, Young),
#  (stuff, Young),
#  (face, Young),
#  (kids, stupid),
#  (country, stupid),
#  (thugz, stupid),
#  (racis, old),
#  (night, busy),
#  (BJ, busy),
#  (food, okay),
#  (bbq, single),
#  (past, single),
#  (21years, single),
#  (dollars, single),
#  (veggie, few),
#  (choices, MOST),
#  (meet, MOST),
#  (IMPORTANTLY, more),
#  (diarrhea, more),
#  (restaurant, more),
#  (diarrhea, more),
#  (years, hungry),
#  (buy, upset),
#  (rationale, terrible),
#  (menu, impossible),
#  (planning, impossible),
#  (vegan, impossible),
#  (burger, impossible),
#  (burger, alternative),
#  (vegan, alternative),
#  (cheese, alternative),
#  (server, alternative),
#  (vegan, alternative),
#  (menu, alternative),
#  (vegan, alternative),
#  (bun, alternative),
#  (form, sad),
#  (bread, sad),
#  (lettuce, sad),
#  (wrap, sad),
#  (bunless, sad),
#  (burger, extra),
#  (veggies, extra),
#  (fries, extra),
#  (side, extra),
#  (Server, extra),
#  (peas, terrible),
#  (carrots, terrible),
#  (vegan, impossible),
#  (burger, impossible),
#  (bar, impossible),
#  (Mandalay, impossible),
#  (Bay, impossible),
#  (restaurant, impossible),
#  (bun, impossible),
#  (burger, few),
#  (Whole, few),
#  (Foods, few),
#  (package, few),
#  (bun, few),
#  (issues, dry),
#  (dog, dry),
#  (Bret, dry),
#  (April, dry),
#  (courtesy, dry),
#  (exam, dry),
#  (body, frozen),
#  (mailing, usual),
#  (kit, usual),
#  (Moreno, usual),
#  (Valley, usual),
#  (exam, sure),
#  (price, sure),
#  (freezer, sure),
#  (days, sure),
#  (Bret, sure),
#  (body, sure),
#  (Preserved, sure),
#  (Pets, sure),
#  (body, irritated),
#  (Preserved, OK),
#  (Pets, OK),
#  (process, last),
#  (week, left),
#  (Bella, left),
#  (eye, cloudy),
#  (brown, fast),
#  (tests, fast),
#  (minutes, fast),
#  (cancer, fast),
#  (glaucoma, fast),
#  (exam, fast),
#  (fee, fast),
#  (courtesy, fast),
#  (appointment, fast),
#  (today, fast),
#  (am, fast),
#  (process, fast),
#  (event, OK),
#  (am, OK),
#  (minutes, OK),
#  (exam, OK),
#  (room, OK),
#  (Bella, same),
#  (hour, same),
#  (tests, same),
#  (Bella, same),
#  (phone, same),
#  (results, same),
#  (wait, nice),
#  (Doctor, nice),
#  (Taylor, nice),
#  (Parker, nice),
#  (Bella, wait),
#  (doubts, wait),
#  (Bret, wait),
#  (passing, wait),
#  (time, actual),
#  (one, last),
#  (heck, last),
#  (Dr., last),
#  (Parker, last),
#  (invoice, last),
#  (receptionist, last),
#  (recheck, last),
#  (week, further),
#  (exam, further),
#  (fee, further),
#  (couple, further),
#  (calls, further),
#  (Dr., further),
#  (LEE, further),
#  (owner, further),
#  (charge, further),
#  (receptionist, further),
#  (Danielle, further),
#  (Janie, further),
#  (vet, further),
#  (tech, further),
#  (assistant, further),
#  (title, further),
#  (exam, receptionist),
#  (fee, receptionist),
#  (Dr., receptionist),
#  (LEE, receptionist),
#  (overrode, receptionist),
#  (decision, receptionist),
#  (Wednesday, receptionist),
#  (vet, receptionist),
#  (Pros, receptionist),
#  (staff, good),
#  (doctors, good),
#  (jobs, caring),
#  (individuals, triple),
#  (Cons, triple),
#  (freezer, triple),
#  (minutes, triple),
#  (testing, triple),
#  (process, triple),
#  (TESTS, triple),
#  (dog, triple),
#  (eye, triple),
#  (time, last),
#  (recheck, last),
#  (fee, last),
#  (days, last),
#  (tests, last),
#  (week, sure),
#  (actuality, sure),
#  (dog, sure),
#  (bill, sure),
#  (Dr., sure),
#  (Choppa, sure),
#  (spelling, cool),
#  (Dr., cool),
#  (Taylor, cool),
#  (Parker, cool),
#  (staff, nearest),
#  (person, nearest),
#  (minutes, nearest),
#  (eye, nearest),
#  (testing, nearest),
#  (Dr., nearest),
#  (LEE, nearest),
#  (receptionist, nearest),
#  (Danielle, nearest),
#  (tech, nearest),
#  (Janie, nearest),
#  (courtesy, nearest),
#  (House, good),
#  (Pizza, good),
#  (night, busy),
#  (lunch, busy),
#  (today, busy),
#  (after1:00, busy),
#  (help, busy),
#  (gentleman, busy),
#  (reason, busy),
#  (Wait, busy),
#  (sign, busy),
#  (helps, busy),
#  (attention, busy),
#  (restaurant, busy),
#  (tables, iced),
#  (people, iced),
#  (order, iced),
#  (Pastrami, iced),
#  (sub, iced),
#  (tea, little),
#  (minutes, little),
#  (lunch, little),
#  (break, little),
#  (work, little),
#  (sub, little),
#  (meat, little),
#  (pastrami, little),
#  (pastrami, little),
#  (meat, little),
#  (flavor, dry),
#  (moisture, dry),
#  (dust, only),
#  (moisture, entire),
#  (sub, nonexistent),
#  (mustard, nonexistent),
#  (drops, nonexistent),
#  (water, nonexistent),
#  (lettuce, nonexistent),
#  (waitress, nonexistent),
#  (tea, good),
#  (minutes, good),
#  (food, good),
#  (place, good),
#  (day, awhile),
#  (chili, bad),
#  (service, worth),
#  (walk, real),
#  (hotel, real),
#  (servers, real),
#  (restaurant, last),
#  (Friday, medium),
#  (size, large),
#  (beef, large),
#  (pho, large),
#  (size, medium),
#  (beef, medium),
#  (tendon, medium),
#  (pho, medium),
#  (vermicelli, medium),
#  (pho, long),
#  (time, long),
#  (tendon, long),
#  (pho, long),
#  (vermicelli, long),
#  (wait, okay),
#  (tables, okay),
#  (food, okay),
#  (waitress, okay),
#  (chef, okay),
#  (orders, okay),
#  (food, okay),
#  (restaurants, total),
#  (Toronto, total),
#  (bill, total),
#  (number, right),
#  (tax, right),
#  (bill, right),
#  (breakdown, right),
#  (item, right),
#  (number, right),
#  (menu, big),
#  (neighbouring, big),
#  (table, big),
#  (calculator, big),
#  (number, big),
#  (money, medium),
#  (cashier, medium),
#  (lady, medium),
#  (beef, large),
#  (pho, large),
#  (size, medium),
#  (size, large),
#  (size, medium),
#  (chef, medium),
#  (beef, medium),
#  (pho, medium),
#  (food, medium),
#  (pot, medium),
#  (bowl, medium),
#  (bowl, wrong),
#  (argument, wrong),
#  (restaurant, wrong),
#  (bowl, large),
#  (size, large),
#  (customer, large),
#  (size, large),
#  (size, medium),
#  (size, large),
#  (lady, large),
#  (bowl, large),
#  (bowl, large),
#  (beef, unhappy),
#  (pho, unhappy),
#  (bill, unhappy),
#  (cents, unhappy),
#  (car, sure),
#  (company, sure),
#  (audi, sure),
#  (A4, sure),
#  (mirror, sure),
#  (car, sure),
#  (day, sure),
#  (guy, sure),
#  (sigb, sure),
#  (yelp, sure),
#  (star, aware),
#  (discount, aware),
#  (experience, particular),
#  (location, last),
#  (night, tiny),
#  (minutes, tiny),
#  (order, tiny),
#  (Waitress, tiny),
#  (friend, tiny),
#  (phone, tiny),
#  (couple, tiny),
#  (beers, tiny),
#  (calamari, tiny),
#  (flesh, interested),
#  (crumbs, interested),
#  (Staffs, interested),
#  (customers, other),
#  (JA, better),
#  (locations, better),
#  (way, better),
#  (complains, prime),
#  (place, prime),
#  (Scarborough, horrible),
#  (location, horrible),
#  (truth, inside),
#  (seating, outside),
#  (seating, small),
#  (tables, noisy),
#  (traffic, cold),
#  (street, cold),
#  (pretzels, cold),
#  (ones, cold),
#  (Service, cold),
#  (cashier, pretzel),
#  (questions, pretzel),
#  (chicken, pretzel),
#  (salad, pretzel),
#  (sandwich, pretzel),
#  (bun, special),
#  (husband, cold),
#  (cheeseburger, cold),
#  (roll, cold),
#  (guys, terrible),
#  (service, last),
#  (leak, last),
#  (Thursday, next),
#  (guys, next),
#  (Monday, next),
#  (repairs, next),
#  (Tuesday, next),
#  (repairs, next),
#  (Tuesday, condescending),
#  (top, condescending),
#  (list, condescending),
#  (apologies, condescending),
#  (manager, condescending),
#  (Mike, condescending),
#  (appointment, able),
#  (problem, crappy),
#  (rest, crappy),
#  (customers, crappy),
#  (customer, crappy),
#  (customer, small),
#  (service, small),
#  (smile, small),
#  (questions, small),
#  (place, small),
#  (business, bad),
#  (name, next),
#  (reason, next),
#  (star, next),
#  (Starbucks, next),
#  (door, old),
#  (day, old),
#  (bread, empty),
#  (racks, empty),
#  (hip, cool),
#  (hotel, practical),
#  (use, high),
#  (space, high),
#  (place, high),
#  (work, high),
#  (-elevators, high),
#  (bit, high),
#  (tech, large),
#  (elevators, large),
#  (touch, large),
#  (screen, large),
#  (elevator, large),
#  (buttons, large),
#  (destination, large),
#  (floor, large),
#  (-NO, large),
#  (desk, large),
#  (corner, steamy),
#  (couch, steamy),
#  (-shower, steamy),
#  (center, steamy),
#  (room, steamy),
#  (shower, entire),
#  (room, hot),
#  (privacy, small),
#  (rooms, small),
#  (-lots, small),
#  (window, good),
#  (ton, good),
#  (drapes, good),
#  (day, good),
#  (service, long),
#  (way, long),
#  (drinks, crowded),
#  (foods, crowded),
#  (checks, crowded),
#  (food, worst),
#  (greasy, worst),
#  (booth, disgusting),
#  (kitchen, disgusting),
#  (top, high),
#  (booth, high),
#  (ground, long),
#  (cashmere, long),
#  (sweater, long),
#  (back, long),
#  (wait, disproportional),
#  (elbows, disproportional),
#  (cashmere, disproportional),
#  (rash, disproportional),
#  (legs, disproportional),
#  (Chicken, Rib),
#  (bland, Rib),
#  (sauce, spicy),
#  (spicy, cooked),
#  (shrimp, cooked),
#  (bread, gross),
#  (shrimp, 8yr),
#  (nephew, dry),
#  (burger, dry),
#  (Service, great),
#  (place, sorry),
#  (AWFUL, sorry),
#  (way, crappy),
#  (food, crappy),
#  (man, crappy),
#  (meal, crappy),
#  (money, crappy),
#  (dollars, crappy),
#  (food, sweet),
#  (chicken, strange),
#  (sauce, strange),
#  (flavor, traditional),
#  (sauce, orange),
#  (jello, thick),
#  (egg, thick),
#  (drop, thick),
#  (soup, thick),
#  (taste, old),
#  (crab, bland),
#  (puffs, bland),
#  (room, tasteless),
#  (temp, tasteless),
#  (bucks, good),
#  (food, good),
#  (money, unethical),
#  (patients, unethical),
#  (being, unethical),
#  (injuries, unethical),
#  (ladder, unethical),
#  (facility, conniving),
#  (place, good),
#  (hoagie, low),
#  (lunch, low),
#  (meat, low),
#  (food, nasty),
#  (Eggs, watery),
#  (cheese, horrible),
#  (top, horrible),
#  (Hash, horrible),
#  (browns, horrible),
#  (rock, horrible),
#  (Service, good),
#  (staff, good),
#  (staff, nice),
#  (wish, same),
#  (hype, awesome),
#  (people????I, awesome),
#  (lunch, awesome),
#  (reviews, disappointed),
#  (menu, hard),
#  (pic, much),
#  (chicken, much),
#  (shwarma, much),
#  (sandwich, much),
#  (hummus, much),
#  (platter, much),
#  (drink, tiny),
#  (selection, tiny),
#  (fridge, few),
#  (soda, few),
#  (cans, few),
#  (lot, few),
#  (people, few),
#  (drinks, few),
#  (market, few),
#  (food, few),
#  (pain, few),
#  (ass, few),
#  (people, garlic),
#  (food, garlic),
#  (while, garlic),
#  (order, garlic),
#  (sauce, small),
#  (lady, small),
#  (nevermind, small),
#  (container, surprised),
#  (condiment, surprised),
#  (sandwich, impressive),
#  (flatbread, few),
#  (pieces, few),
#  (chicken, few),
#  (tomato, little),
#  (slices, little),
#  (lettuce, little),
#  (sauce, worth),
#  (opinion, worth),
#  (size, little),
#  (hummus, good),
#  (place, dodgy),
#  (part, cool),
#  (town, cool),
#  (project, cool),
#  (housing, cool),
#  (street, cool),
#  (market, cool),
#  (return, olive),
#  (daylight, olive),
#  (course, olive),
#  (olives, olive),
#  (yogurtology, quick),
#  (evening, quick),
#  (yogurt, full),
#  (minutes, unprofessional),
#  (floors, unprofessional),
#  (toppings, unprofessional),
#  (yogurt, unprofessional),
#  (machines, unprofessional),
#  (workers, awkward),
#  (yogurt, awkward),
#  (toppings, awkward),
#  (star, bad),
#  (service, mediocre),
#  (capriottis, best),
#  (experience, same),
#  (caps, same),
#  (Sahara, same),
#  (hubby, same),
#  (owner, sorry),
#  (girl, sorry),
#  (close, sorry),
#  (work, sorry),
#  (response, sorry),
#  (owner, other),
#  (place, professional),
#  (competition, professional),
#  (place, better),
#  (Crap, fried),
#  (chicken, overpriced),
#  (thighs, overpriced),
#  (ham, overpriced),
#  (hock, overpriced),
#  (collard, overpriced),
#  (greens, overpriced),
#  (Navy, overpriced),
#  (Pier, overpriced),
#  (tourist, overpriced),
#  (trap, overpriced),
#  (food, excellent),
#  (combination, same),
#  (joke, pathetic),
#  (pork, stale),
#  (slider, stale),
#  (potato, stale),
#  (chips, stale),
#  (oil, stale),
#  (stale, stale),
#  (slider, stale),
#  (bun, stale),
#  (thing, stale),
#  (hours, pulled),
#  (pork, nice),
#  (pedestrian, nice),
#  (taste, high),
#  (pork, high),
#  (school, tiny),
#  (cafeteria, tiny),
#  (room, tiny),
#  (temperature, tiny),
#  (teeny, tiny),
#  (cup, deviled),
#  (flavorless, deviled),
#  (coleslaw, deviled),
#  (egg, best),
#  (egg, best),
#  (part, real),
#  (dish, real),
#  (egg, special),
#  (egg, first),
#  (disappointment, first),
#  (place, first),
#  (years, first),
#  (chef, first),
#  (place, fine),
#  (competition, fine),
#  (street, fine),
#  (girls, fine),
#  (manager, uncomfortable),
#  (package, uncomfortable),
#  (life, upset),
#  (manager, upset),
#  (chair, upset),
#  (chair, upset),
#  (hair, upset),
#  (chair, upset),
#  (hair, funny),
#  (mirror, funny),
#  (fit, funny),
#  (thing, entire),
#  (owner, entire),
#  (phone, entire),
#  (package, bad),
#  (salon, awesome),
#  (competition, awesome),
#  (Frank, awesome),
#  (Floyd, awesome),
#  (Wright, awesome),
#  (customer, warm),
#  (service, warm),
#  (package, sorry),
#  (purchase, sorry),
#  (place, sorry),
#  (girls, Funny),
#  (women, Funny),
#  (yesterday, salty),
#  (dinner, salty),
#  (Pho, salty),
#  (food, sick),
#  (poisoning, sick),
#  (Girlfriend, sick),
#  (tapas, honest),
#  (empanadas, expensive),
#  (menu, expensive),
#  (boy, expensive),
#  (mistake, expensive),
#  (dishes, many),
#  (size, many),
#  (empanadas, small),
#  (one, regular),
#  (tapas, regular),
#  (meals, delicious),
#  (Passion, delicious),
#  (Fruit, delicious),
#  (sangria, delicious),
#  (apple, refreshing),
#  (orange, refreshing),
#  (lemon, refreshing),
#  (pitcher, delicious),
#  (bread, delicious),
#  (meal, delicious),
#  (basket, thin),
#  (ice, thin),
#  ...]

# %% [markdown]
# #### Find the top 10 most frequent noun-adjective pairs

# %%
# (i found a few diff methods online to find the most frequent pair)
# method 1
 
def most_frequent(List):
    counter = 0
    num = List[0]
     
    for i in List:
        curr_frequency = List.count(i)
        if(curr_frequency> counter):
            counter = curr_frequency
            num = i
 
    return num
 
print(most_frequent(noun_adj_pairs))
# Out:
# (WARNING, little)

# %%
# method 2
def most_common(lst):
    return max(set(lst), key=lst.count)
print(most_common(noun_adj_pairs))
# Out:
# (face, Young)

# %%
# method 3
import itertools
import operator

def most_common(L):
  # get an iterable of (item, iterable) pairs
  SL = sorted((x, i) for i, x in enumerate(L))
  # print 'SL:', SL
  groups = itertools.groupby(SL, key=operator.itemgetter(0))
  # auxiliary function to get "quality" for an item
  def _auxfun(g):
    item, iterable = g
    count = 0
    min_index = len(L)
    for _, where in iterable:
      count += 1
      min_index = min(min_index, where)
    # print 'item %r, count %r, minind %r' % (item, count, min_index)
    return count, -min_index
  # pick the highest-count/earliest item
  return max(groups, key=_auxfun)[0]

most_common(noun_adj_pairs)
# Out:
# (WARNING, little)

# %%
print(noun_adj_pairs[5])
# Out:
# (family, big)

# %%
# (Using df instead of list)
# Convert list to dataframe
df = pd.DataFrame (noun_adj_pairs, columns = ['noun','adj'])
display(df)
# Out:
#               noun        adj
# 0          WARNING     little
# 1           Haters     little
# 2          Chicken        Rib
# 3             Crap      fried
# 4          husband  wonderful
# ...            ...        ...
# 1207  receptionist    nearest
# 1208      Danielle    nearest
# 1209          tech    nearest
# 1210         Janie    nearest
# 1211      courtesy    nearest
#
# [1212 rows x 2 columns]

# %%
df.sort_values(by=['adj'], ascending=False)
# Out:
#           noun       adj
# 1211  courtesy   nearest
# 1205       Dr.   nearest
# 1200     staff   nearest
# 1201    person   nearest
# 1202   minutes   nearest
# ...        ...       ...
# 15         hip      cool
# 12       chili       bad
# 5       family       big
# 3         Crap     fried
# 7         guys  terrible
#
# [1212 rows x 2 columns]

# %%
# Find top 10 most frequent noun-adj pairs
n = 10
df.value_counts()[:n].index.tolist()
# Out:
# [(courtesy, nearest),
#  (empanadas, small),
#  (couple, tiny),
#  (sandwich, much),
#  (xtra, extra),
#  (menu, alternative),
#  (beef, underwhelming),
#  (man, hungry),
#  (sound, first),
#  (Service, great)]

# %%
# Find top 10 most frequent noun-adj pairs
df.value_counts()[:10].sort_values(ascending=False)
# Out:
# noun       adj
# courtesy   nearest          1
# empanadas  small            1
# couple     tiny             1
# sandwich   much             1
# xtra       extra            1
# menu       alternative      1
# beef       underwhelming    1
# man        hungry           1
# sound      first            1
# Service    great            1
# dtype: int64

# %%
df['adj'].value_counts()[df['adj'].value_counts() == df['adj'].value_counts().max()]
# Out:
# good    16
# Name: adj, dtype: int64
