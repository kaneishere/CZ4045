# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import spacy
import collections

from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
data = pd.read_json('reviewSelected100.json',lines=True, 
                    orient='records',encoding = "ISO-8859-1")

# %%
display(data)
# Out:
#                     review_id                 user_id             business_id  \
# 0      8aoJJdKEO3ypoZNszpPu7Q  bGgAL09pxLnV_FFgR4ZADg  ZBE-H_aUlicix_9vUGQPIQ
# 1      J5NOCLdhuhor7USRhtYZ8w  pFCb-1j6oI3TDjr26h2cJQ  e-YnECeZNt8ngm0tu4X9mQ
# 2      PXiLWAYRt3xnHaJ8MB4rzw  mEzc6LeTNiQgIVsq3poMbg  j7HO1YeMQGYo3KibMXZ5vg
# 3      VrLarvxZYJm74yAqtpe9PQ  o-zUN2WEZgjQS7jnNsec0g  7e3PZzUpG5FYOTGt3O3ePA
# 4      C1CUpidlVFprUCkApqzCmA  Wlx0iBXJvk4x0EeOt2Bz1Q  vuHzLZ7nAeT-EiecOkS5Og
# ...                       ...                     ...                     ...
# 15295  qknwFVEh_0KSuexigYBI_A  YMGmyPOU65SMs4H60ltYiw  shIPnFoXrL3dFo5HLH1_HA
# 15296  Y-ZRoyAXCukBK1uK1ZcZCA  JLhOWQiWtGbr14K_KmoWxA  zPEYgVqJ2QNKi45FJi2jvg
# 15297  A8HdjBfhj3pgQuSbwNtDEw  6CoiKFDFXIACJZvv_I_8mQ  zPEYgVqJ2QNKi45FJi2jvg
# 15298  2n1QdrYBRAAe6GKaxEV0jA  _fH4s3ls08eSl_PfX38KIA  etzDsNjkCyQBoJcU2a3U-g
# 15299  4B9k5hmmLWV_lhIYvVcPWA  msRUiBE7Sa5A9145ZdFBow  9Xm2GfG8Rnbb1_CmXyrm3g
#
#        stars  useful  funny  cool  \
# 0          5       0      0     0
# 1          4       0      0     0
# 2          5       2      1     3
# 3          3       0      0     0
# 4          1      11      0     3
# ...      ...     ...    ...   ...
# 15295      1       2      0     0
# 15296      5       0      0     0
# 15297      1       0      1     0
# 15298      5       0      0     0
# 15299      5       0      0     0
#
#                                                     text                date
# 0      We had my Mother's Birthday Party here on 10/2... 2016-11-09 20:07:25
# 1      Good Korean grill near Eaton Centre. The marin... 2015-12-05 05:06:43
# 2      Was recommended to try this place by few peopl... 2014-10-11 05:16:15
# 3      Ambience: Would not expect something this nice... 2016-07-25 03:45:26
# 4      Absolutely the WORST pool company that I have ... 2016-04-11 18:49:11
# ...                                                  ...                 ...
# 15295  This was the worst experience ever. So much so... 2014-07-12 21:58:15
# 15296  We come here every time we hit Vegas! A giant ... 2018-11-10 21:38:49
# 15297  As locals we used  to the this place when it w... 2018-10-13 22:11:22
# 15298  The food was delicious. We were seated in 15 m... 2015-02-15 08:43:46
# 15299  Wonderful spot (the patio) and OH SO EXCELLENT... 2018-10-06 19:00:13
#
# [15300 rows x 9 columns]

# %% [markdown]
# ## 1 star ratings
# #### Randomly select 50 reviews from different businesses with rating 1

# %%
# Filter reviews with 1 star and store in a dataframe
oneStar = data[data['stars']==1]

# %%
# Group by business ID and sample a random 1-star review from each group (1 per business)
grouped = oneStar.groupby('business_id').sample(n=1)
len(grouped)
# Out:
# 150

# %%
# Randomly select 50 reviews of rating 1 (one from each business)
random50 = grouped.sample(n=50)
#len(random50)
display(random50)
# Out:
#                     review_id                 user_id             business_id  \
# 8577   emYQOcg_Re43kxCPGW3RpQ  l4OTbLGo3EQL-TliY9lvRg  WO3L0pmtAO8ozspmaVdHIg
# 11430  gKsEKC7RvWXq5JCRjQoCrQ  aG_z7gOQkbHXK-iYdtcZCw  nN1MXnHFzZh9snkMmdhYrg
# 2922   IMYOlPgqcl9BUHtQm5nkIQ  2iuAprO_yJi6Bym8481Sxg  NV5Q8ZhDSh_oI8ZOnn72Lw
# 8294   Dl2NMgDLjGc6pS1vLbgs5Q  0FJkf0Q2Nnx3Y9RC1QpGFw  daqYMX3Y4QR8xl-BUlYBPw
# 3815   Cse_npPWYK1X6itIJS_20Q  Mjr1MbDqNPNafh8g-s7WSg  kAmNIcJpAZIZIp5uSMAYLA
# 2823   AghC4O87C-N58Ca9Qg8fsw  Lsbcp7XZnL3Wz418Z4xsIw  CQxhyLM833WF45yrS9yeAA
# 1539   AtWVwDEBJzvw9Mo8EEv4kQ  jtQ0APGyfkocntNQqJLUBA  e-YnECeZNt8ngm0tu4X9mQ
# 8589   miUsLh09nvEo9C8QLcJ4tQ  V-db1AtNtOktXfkvzYfNjg  XGaa9NDCwOJ9v0Cj55p28w
# 1544   0PbV9F-XFW1AXJY3yyvUxQ  V4D4x4QtDB-tmXkwdxgwDA  7e3PZzUpG5FYOTGt3O3ePA
# 8172   YRBua1xK0Fr74-n1rfySEw  E5HuudDfM3K8CXnSB0NOUA  y5fwt6pAKnvYOSn-xOUepA
# 6537   DaUfBMQ9cbc8p9YY_F1Atg  YLyFQ9VVBoqqPIiUeDvVZw  Jol7cXrDmKKmu_V6qp4wMA
# 13610  M3gVg_LlEZQaxRqnY32dRw  6nSGen1iDqt5r97yxEFULA  9Xm2GfG8Rnbb1_CmXyrm3g
# 5445   wpsEmC92TGrcZgW85R4-JQ  dzoWI3L4RgV1FD0fOU1B1Q  XuZ9pksVQBIpmVQm6UO2YQ
# 8971   Bd_fzgkfRFc3CgoMydfA6A  mvC-x4kQcwtYM0H3NwHU4g  dOgvND5x_MKMBkqI3GvZXA
# 14666  1TtoSlgMZMtXVnVa-tQPYw  OCbh2N_na0FB0TrTsaAyJg  s7keQ0-OQ5Li_IKGKVTarw
# 4842   CZJE7Brv_w80k3iMFII4yw  9kDHnx4bMqT23jC4Dw06Mg  IUMyUYOIR9UQ7XGIEQKOuA
# 11947  kVnIEeg01D6yiKYvENTTzA  CsAmdmXh55wfJMhVxt4mOA  WA7sC64kCRstywm2EgZXEw
# 206    ZBbfgd5IKbZJetl7fV2bRA  ReA8W1_5sAkGsVvEnBB8ww  z8Em-bhZI3Mmspml7tj6tg
# 7476   QcIbQ0BJ0B3q3xlUMCUMlQ  0JCtOdVeOE-yI-qeFv0vcQ  3kUqNxO1rkDDb89GAfyNgw
# 11116  id7CGCfMgvw8N8hl57JiFg  jFqQT_PS4kRhBChcO05VDg  rN3gHTjqx5sOnoUpJ-6jyg
# 3875   cLsUAXlnHFC8DZmaSoq2bw  XrrQVZ6mv-YY82MwafaEfA  S6apFS5ghsQg69rcBvm2Qg
# 3908   ktNsqKW53uvhCeP_85k8Bw  Nnql7OE52NcWtyvYOB6FNw  spDZkD6cp0JUUm6ghIWHzA
# 3065   6h2h52fuFStB_M1K26Zuaw  Sa7sybxj5YuZIZKsbN4jFw  paCgjLEUEVM38VZ6Sjghgg
# 9783   WaIeqKRjArdq8nHTtK0Wxg  lLBk81TVPJ6YuExEXTYcww  PyMcV7WSYVqg1_S29G109g
# 1134   XvtCi0bWSYjafGeE1ODllg  MzHefdSrnAVxhZ2zkfENYA  pJnN5PxqFPGZW2pJWkQtzA
# 2269   K6o7xeSIMdlDEZS_ufOPvw  rlhMI5vfR-Tv5o8V9m-BHQ  vxuyl9IVum8zngXgvbT4Jg
# 14935  9_IL5nG2wPZR1XdHzrslpQ  _xEw7D-qZ4DL2rOD5ZWPvg  cPzIic1AqH1ApTVVaww5hw
# 12454  mCFHLk2OzrP2gHKxm6xwbA  X6ZYcQj7bHLJ15DJ5SziWg  d8Kz48UDfZ0MPuQpGy2r0Q
# 9621   tgJmn9YWFWxxbUbHh194Nw  EdDmKiz6V89g6Dws9I4AKA  7vvliv5R0MD7BQ2CsquhcQ
# 10834  -5oZ_LHXB_HVwuzoHoYfSw  ajC8bO6DbLA_ieHy811yFA  x_4gEfC25uiX21NyYdohgQ
# 12700  M6P8SprZYxa4s-jHkWRrjg  usBYFeH-ciHXpF_4RnbSkw  -7XWJYkutqhIxLen7Grg1g
# 867    zMPiTlx5XsWv7r5AmSiq3Q  7KIV3vskRl4sw3cRFXMm7Q  j7HO1YeMQGYo3KibMXZ5vg
# 11395  E33dZbqmqscMTKfUKnHVIw  O9GoYQxWPt74oQNngTbFPg  eWmARaQb_9vxq-zy5PVvXA
# 7257   1AkYqsnBHE7-2PWwnPtX4Q  KK_RrGJ0OEZwFEooJQAWqw  LScYNYAA78iQL6pWOqt-WQ
# 9979   41Lw0WHhNmqIm65bDsojfw  YKcgujKz8fdktdENxQGy6Q  suJ-eo5Gkvcg0iXVQw4RyA
# 813    XmaZJ9gH9AxUuU8h_FI2pg  -cWjI2heWmLszz-oPHbnyg  k99YNCx5KcQPR7oeTgAOzg
# 7876   j-De6im_y5KTuV-8YX_eXg  IvCQV_zz9R_aybqWGjOGvQ  8Z72HW5ydzQFydUxZglurg
# 29     b0xlv66a0QrHlcXeB1Jh7A  FeCsroX40iVjMWi3IIOvoA  QeEQXdto_4wFRaNKyIygRA
# 13743  cdktoe7Vfzds8FDmuLkZ0Q  heqV8fuYyjDCyRHp9GFmlw  mSqR24h_nKXyMhwtWSih3Q
# 10728  Z_tpD6mg3FcPFoZqxyOksw  AArhVXFj0Su5EfngmyGPyg  i-2OzvZUDtvKCMq1vcRSZg
# 14833  p6bY_1HXSdgIdPaIAmEzBw  _X1GaFa9zbH52bUU82MEqQ  IB_aESRBh2cmYWSF6Fv0jQ
# 10763  heZv00MwKpUxI6LXluIRqw  tz-p0tqdPLukqul4BQbh3A  ZP7U4qUCMjIvasWV7a_mgg
# 13964  iRpqfFqSD-C-PX6JD8_fjw  bDvQRiHi4diu2cTupl7NWA  shIPnFoXrL3dFo5HLH1_HA
# 12609  1GYat4anQVbdIBzlCHWCZQ  aYz7yCK598WbOqyFgrYpDw  QqGMtc24VdCzYAajw1g4bA
# 8947   IpInuNxfC_FkLNPUlXG1hw  NJ90ZRPYPfDqixQlC_9I_w  Gr_TkW3iFdgahixONGBsww
# 3023   RJfVRWPUtEPslzBfuTdZaQ  eN62Dzfylx8HU0YXfdOsNA  oICXzFAaUMrYGzjRWmkw4Q
# 11877  REe3w0vGBmVxXCZ0xOmfpg  GHP0zVzInzoxUm_5nPK6KQ  z_RTK0MaxaRHRQ99hDL2QA
# 2130   92I3J7VHixNWfGZD5d2cUA  rBK8_HO5pVEa4_dJl0qL0g  sWh-N7K3ebRHZKhhH01mJQ
# 1478   7cCiL30lXNt2uS6-o3574w  2v38YzoFeOjeRy4O92d2tw  vuHzLZ7nAeT-EiecOkS5Og
# 13778  YRDA-Fm1hWoD8tpac7OMew  _DpQ25-kJ2RBQ6yplqSwcQ  qMyYY8zpHusOXUd6wmqX2w
#
#        stars  useful  funny  cool  \
# 8577       1       0      1     0
# 11430      1       2      0     1
# 2922       1       0      0     0
# 8294       1       0      0     0
# 3815       1       4      3     0
# 2823       1       9      0     2
# 1539       1       0      0     0
# 8589       1       0      0     0
# 1544       1       0      0     0
# 8172       1       1      1     1
# 6537       1       3      0     1
# 13610      1       2      1     0
# 5445       1       1      1     0
# 8971       1       0      0     0
# 14666      1       1      3     0
# 4842       1       1      0     0
# 11947      1       2      1     1
# 206        1       0      0     0
# 7476       1       4      0     0
# 11116      1       0      0     0
# 3875       1       2      1     1
# 3908       1       1      0     0
# 3065       1       1      1     0
# 9783       1       2      0     0
# 1134       1       2      1     0
# 2269       1       0      0     0
# 14935      1       3      0     0
# 12454      1       4      0     0
# 9621       1       3      0     1
# 10834      1       1      0     0
# 12700      1       2      1     0
# 867        1       0      0     0
# 11395      1       1      0     1
# 7257       1       0      0     0
# 9979       1       0      0     0
# 813        1       2      1     0
# 7876       1       2      0     0
# 29         1       0      0     0
# 13743      1       1      0     1
# 10728      1       0      0     0
# 14833      1       0      0     0
# 10763      1       0      0     0
# 13964      1       0      0     0
# 12609      1       1      2     1
# 8947       1       3      0     2
# 3023       1       0      0     0
# 11877      1       0      0     0
# 2130       1       3      0     0
# 1478       1       5      1     2
# 13778      1       0      0     0
#
#                                                     text                date
# 8577   Even though I picked one star, that was becaus... 2016-08-07 00:30:48
# 11430  I was visiting from out of town and thought I ... 2017-05-26 21:39:47
# 2922   I had a veggie burger and poutine. The place i... 2018-10-18 20:37:59
# 8294   Deplorable customer service, wilted vegetables... 2013-04-09 17:21:21
# 3815   DO NOT RENT FROM HERE- \n-seriously save yours... 2016-04-27 19:39:54
# 2823   To those they helped...i'm glad for you. But y... 2013-06-21 19:10:52
# 1539   Terrible terrible terrible. They serve meat in... 2016-08-01 02:58:28
# 8589   $2000 bottle service leads to your table given... 2017-01-15 08:47:37
# 1544   Had Dinner there. Bill of two for an Appetizer... 2010-04-22 21:36:10
# 8172   One of the few restaurants that I went to with... 2010-02-18 20:51:06
# 6537   What is the hype people????I went here for lun... 2010-03-25 18:18:35
# 13610  Voted the absolute worst chicken wings in Char... 2018-02-25 03:36:38
# 5445   The chef pretended he knew what gluten was. He... 2014-10-16 01:15:54
# 8971   I was excited to visit this place.  I called i... 2018-08-12 12:59:43
# 14666  We had a great experience. It was a younger gi... 2017-08-26 19:10:05
# 4842   Well I wanted to write this review a week ago ... 2018-06-07 21:00:31
# 11947  There are few times I have been so rarely disa... 2016-05-09 18:43:36
# 206    I ordered and paid for a pound of barbeque por... 2015-02-17 22:00:43
# 7476   I went there for a custom facial. If the girl ... 2014-09-29 04:07:49
# 11116  Service was good, ambience nice\nFood lousy. W... 2016-05-28 01:38:44
# 3875   I will not be going back to this Capriotti's S... 2013-11-26 22:09:41
# 3908   This place is utterly disturbing. The fact tha... 2015-09-05 19:17:49
# 3065   This place has potential but unfortunately the... 2017-11-12 04:38:52
# 9783   Man I hope I got my oil changed didn't seem li... 2018-03-18 00:42:19
# 1134   After trying to order on Yelp and being told I... 2016-03-03 22:47:12
# 2269   Always love Freddy's food, but tonight on Mond... 2018-10-02 05:02:55
# 14935  I went there for lunch with a friend. They sat... 2015-08-17 15:33:41
# 12454  I have attempted to eat at Kost twice. I would... 2018-07-16 19:38:25
# 9621   Disappointing coffee and service ever!!\nIt wa... 2016-11-26 18:40:27
# 10834  If i could give them a 0 i would there food is... 2013-01-13 03:51:14
# 12700  WORST! I repeat WORST experience ever! The cus... 2016-04-09 02:31:49
# 867    Average food. Was okay but have had much bette... 2013-03-29 19:13:28
# 11395  This is total BS AND I would know as I am well... 2017-08-31 03:11:14
# 7257   Just moved to NoDa this week and decided to tr... 2017-01-15 05:42:04
# 9979   I don't know where to begin. This was the abso... 2015-06-14 23:34:25
# 813    If I could give a 0, I would. \n\n\nOn October... 2015-10-16 02:16:52
# 7876   Amending this due to both my moms boyfriend an... 2016-04-18 13:29:59
# 29     We walked in at 10:40 and sat at a table right... 2018-08-04 23:29:52
# 13743  It is a very bad experience. I came in today, ... 2016-09-09 00:33:33
# 10728  I thought this place would be good. Had the It... 2018-05-06 14:03:10
# 14833  Purchase went fine. They sold us a warranty sa... 2017-07-05 22:55:44
# 10763  This restaurant in this location was the absol... 2018-04-01 20:54:57
# 13964  I usually come here to see Ila for my threadin... 2018-03-18 18:29:34
# 12609  Wow.  Just called in for takeout.   Their resp... 2016-06-19 13:19:06
# 8947   This is a beautiful hotel, in a wonderful loca... 2015-05-20 13:24:17
# 3023   Pho was okay and crap. Will never ever try aga... 2018-11-11 02:38:08
# 11877  It tastes like card board.\n\nDear Pittsburgh,... 2016-06-28 14:00:33
# 2130   Just as bad as MedPost. Took my $150 copay and... 2018-05-23 03:35:49
# 1478   Pros: Started our services with AP approx 2 1/... 2017-02-08 02:52:01
# 13778  This is my first and last time I'll be going h... 2018-09-16 23:16:58

# %% [markdown]
# #### Extract all noun-adjective pairs

# %%
nlp = spacy.load('en_core_web_sm')
noun_adj_pairs = []

for i in random50['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((str(token),str(doc[j])))
              break
noun_adj_pairs
# Out:
# [('star', 'honest'),
#  ('stars', 'honest'),
#  ('review', 'horrible'),
#  ('place', 'horrible'),
#  ('husband', 'orange'),
#  ('sample', 'orange'),
#  ('chicken', 'orange'),
#  ('associates', 'orange'),
#  ('response', 'orange'),
#  ('samples', 'orange'),
#  ('chicken', 'orange'),
#  ('batter', 'orange'),
#  ('jam', 'sweet'),
#  ('chicken', 'only'),
#  ('girl', 'nice'),
#  ('plate', 'extra'),
#  ('plate', 'horrible'),
#  ('meal', 'extra'),
#  ('town', 'rude'),
#  ('shampoo', 'rude'),
#  ('blowout', 'rude'),
#  ('woman', 'unaccommodating'),
#  ('confirmation', 'unaccommodating'),
#  ('appointment', 'unaccommodating'),
#  ('mistake', 'unaccommodating'),
#  ('part', 'unaccommodating'),
#  ('person', 'unaccommodating'),
#  ('day', 'next'),
#  ('glitz', 'kindest'),
#  ('booking', 'kindest'),
#  ('Scott', 'kindest'),
#  ('Damon', 'kindest'),
#  ('Salon', 'kindest'),
#  ('stylist', 'same'),
#  ('veggie', 'dirty'),
#  ('burger', 'dirty'),
#  ('poutine', 'dirty'),
#  ('place', 'dirty'),
#  ('HERE-', 'good'),
#  ('amenities', 'good'),
#  ('reason', 'worst'),
#  ('years', 'worst'),
#  ('living', 'better'),
#  ('experience', 'better'),
#  ('management', 'cool'),
#  ('jobs', 'cool'),
#  ('MAINTENANCE', 'cool'),
#  ('GUYS', 'cool'),
#  ('AWESOME', 'cool'),
#  ('time', 'own'),
#  ('problem', 'own'),
#  ('office', 'own'),
#  ('pictures', 'awful'),
#  ('place', 'first'),
#  ('Garbage', 'first'),
#  ('ground', 'first'),
#  ('place', 'first'),
#  ('floor', '3rd'),
#  ('company', 'dirty'),
#  ('maintenance', 'dirty'),
#  ('blower', 'dirty'),
#  ('machine', 'dirty'),
#  ('things', 'dirty'),
#  ('ground', 'dirty'),
#  ('dirt', 'dirty'),
#  ('dust', 'dirty'),
#  ('window', 'dirty'),
#  ('stuff', 'dirty'),
#  ('am', 'big'),
#  ('phones', 'big'),
#  ('resident', 'open'),
#  ('time', 'open'),
#  ('stories', 'safe'),
#  ('people', 'safe'),
#  ('cars', 'safe'),
#  ('people', 'safe'),
#  ('property', 'safe'),
#  ('place', 'safe'),
#  ('money', 'friendly'),
#  ('time', 'friendly'),
#  ('office', 'friendly'),
#  ('people', 'friendly'),
#  ('days', 'large'),
#  ('330am', 'large'),
#  ('yesterday', 'large'),
#  ('dog', '24hr'),
#  ('recording', '24hr'),
#  ('hr', '24hr'),
#  ('service', '24hr'),
#  ('places', '24hr'),
#  ('town', '24hr'),
#  ('home', 'other'),
#  ('care', 'other'),
#  ('terrible', 'small'),
#  ('meat', 'small'),
#  ('trays', 'worried'),
#  ('lots', 'worried'),
#  ('juice', 'worried'),
#  ('contamination', 'Most'),
#  ('Waiters', 'sesame'),
#  ('oil', 'red'),
#  ('salt', 'red'),
#  ('guy', 'red'),
#  ('sauce', 'worse'),
#  ('cost', 'worse'),
#  ('Kimchi', 'slimy'),
#  ('bottle', 'single'),
#  ('service', 'single'),
#  ('table', 'single'),
#  ('garbage', 'single'),
#  ('floor', 'single'),
#  ('hours', 'single'),
#  ('drink', 'multiple'),
#  ('services', 'multiple'),
#  ('drink', 'multiple'),
#  ('flights', 'same'),
#  ('stairs', 'same'),
#  ('entertainer', 'same'),
#  ('Dinner', 'large'),
#  ('Bill', 'large'),
#  ('Appetizer', 'large'),
#  ('steaks', 'large'),
#  ('No', 'large'),
#  ('Dessert', 'large'),
#  ('Glasses', 'large'),
#  ('house', 'large'),
#  ('wine', 'large'),
#  ('Waiter', 'large'),
#  ('party', 'sporadic'),
#  ('service', 'sporadic'),
#  ('Steaks', 'rare'),
#  ('Medium', 'rare'),
#  ('Medium', 'rare'),
#  ('steaks', 'rare'),
#  ('side', 'cubed'),
#  ('steak', 'cubed'),
#  ('charcoal', 'cubed'),
#  ('black', 'cubed'),
#  ('spite', 'cubed'),
#  ('Manager', 'cubed'),
#  ('table', 'cubed'),
#  ('steak', 'cubed'),
#  ('appetizer', 'cubed'),
#  ('Au', 'cubed'),
#  ('Gratin', 'cubed'),
#  ('potatoes', 'cubed'),
#  ('restaurants', 'best'),
#  ('yelp', 'best'),
#  ('review', 'best'),
#  ('part', 'entire'),
#  ('experience', 'bland'),
#  ('sangria', 'bland'),
#  ('tapas', 'bland'),
#  ('paella', 'good'),
#  ('desert', 'good'),
#  ('waste', 'good'),
#  ('hype', 'awesome'),
#  ('people????I', 'awesome'),
#  ('lunch', 'awesome'),
#  ('reviews', 'disappointed'),
#  ('menu', 'hard'),
#  ('pic', 'much'),
#  ('chicken', 'much'),
#  ('shwarma', 'much'),
#  ('sandwich', 'much'),
#  ('hummus', 'much'),
#  ('platter', 'much'),
#  ('drink', 'tiny'),
#  ('selection', 'tiny'),
#  ('fridge', 'few'),
#  ('soda', 'few'),
#  ('cans', 'few'),
#  ('lot', 'few'),
#  ('people', 'few'),
#  ('drinks', 'few'),
#  ('market', 'few'),
#  ('food', 'few'),
#  ('pain', 'few'),
#  ('ass', 'few'),
#  ('people', 'garlic'),
#  ('food', 'garlic'),
#  ('while', 'garlic'),
#  ('order', 'garlic'),
#  ('sauce', 'small'),
#  ('lady', 'small'),
#  ('nevermind', 'small'),
#  ('container', 'surprised'),
#  ('condiment', 'surprised'),
#  ('sandwich', 'impressive'),
#  ('flatbread', 'few'),
#  ('pieces', 'few'),
#  ('chicken', 'few'),
#  ('tomato', 'little'),
#  ('slices', 'little'),
#  ('lettuce', 'little'),
#  ('sauce', 'worth'),
#  ('opinion', 'worth'),
#  ('size', 'little'),
#  ('hummus', 'good'),
#  ('place', 'dodgy'),
#  ('part', 'cool'),
#  ('town', 'cool'),
#  ('project', 'cool'),
#  ('housing', 'cool'),
#  ('street', 'cool'),
#  ('market', 'cool'),
#  ('return', 'olive'),
#  ('daylight', 'olive'),
#  ('course', 'olive'),
#  ('olives', 'olive'),
#  ('chicken', 'HUGE'),
#  ('wings', 'HUGE'),
#  ('Charlotte', 'HUGE'),
#  ('disappointment', 'delicious'),
#  ('restaurant', 'delicious'),
#  ('chicken', 'delicious'),
#  ('food', 'delicious'),
#  ('wings', 'tiniest'),
#  ('chicken', 'tiny'),
#  ('wings', 'tiny'),
#  ('sauce', 'tiny'),
#  ('wings', 'bad'),
#  ('pieces', 'bad'),
#  ('carrots', 'bad'),
#  ('dollars', 'bad'),
#  ('%', 'bad'),
#  ('success', 'bad'),
#  ('rate', 'bad'),
#  ('businesses', 'bad'),
#  ('service', 'bad'),
#  ('cheese', 'busy'),
#  ('order', 'busy'),
#  ('ranch', 'busy'),
#  ('plate', 'busy'),
#  ('napkins', 'busy'),
#  ('table', 'busy'),
#  ('bins', 'busy'),
#  ('table', 'busy'),
#  ('upstairs', 'busy'),
#  ('bar', 'busy'),
#  ('tender', 'busy'),
#  ('chef', 'odd'),
#  ('Celiac', 'odd'),
#  ('Disease', 'odd'),
#  ('waitress', 'odd'),
#  ('times', 'odd'),
#  ('ingredients', 'odd'),
#  ('rice', 'odd'),
#  ('avacodo', 'odd'),
#  ('cucumber', 'odd'),
#  ('salmon', 'odd'),
#  ('chef', 'odd'),
#  ('tofu', 'odd'),
#  ('soy', 'odd'),
#  ('sauce', 'odd'),
#  ('reason', 'continual'),
#  ('asking', 'surprised'),
#  ('verification', 'surprised'),
#  ('wheat', 'surprised'),
#  ('soy', 'surprised'),
#  ('sauce', 'surprised'),
#  ('place', 'kid'),
#  ('place', 'kid'),
#  ('daughter', 'dirty'),
#  ('lady', 'dirty'),
#  ('people', 'dirty'),
#  ('kids', 'dirty'),
#  ('time', 'dirty'),
#  ('place', 'dirty'),
#  ('sewage', 'old'),
#  ('restaurant', 'old'),
#  ('fire', 'cool'),
#  ('station', 'cool'),
#  ('idea', 'nice'),
#  ('staff', 'nice'),
#  ('flight', 'good'),
#  ('beer', 'good'),
#  ('kid', 'friendly'),
#  ('place', 'safe'),
#  ('restaurant', 'safe'),
#  ('experience', 'younger'),
#  ('girl', 'pleasant'),
#  ('daughter', 'pleasant'),
#  ('nails', 'pleasant'),
#  ('day', 'whole'),
#  ('nails', 'whole'),
#  ('pieces', 'rude'),
#  ('problem', 'rude'),
#  ('day', 'rude'),
#  ('owner', 'rude'),
#  ('guarantee', 'rude'),
#  ('worker', 'rude'),
#  ('care', 'rude'),
#  ('pedicure', 'rude'),
#  ('guy', 'rude'),
#  ('picture', 'rude'),
#  ('daughter', 'rude'),
#  ('girl', 'rude'),
#  ('times', 'rude'),
#  ('co', 'rude'),
#  ('-', 'rude'),
#  ('workers', 'rude'),
#  ('English', 'rude'),
#  ('hour', 'rude'),
#  ('SHE', 'rude'),
#  ('1HOUR', 'rude'),
#  ('pedicures', 'rude'),
#  ('SIT', 'different'),
#  ('HOUR', 'different'),
#  ('RUDE', 'different'),
#  ('owner', 'different'),
#  ('daughter', 'different'),
#  ('salon', 'bad'),
#  ('nails', 'bad'),
#  ('nails', 'better'),
#  ('salon', 'bad'),
#  ('star', 'original'),
#  ('girl', 'only'),
#  ('review', 'multiple'),
#  ('week', 'multiple'),
#  ('sclerosis', 'old'),
#  ('visit', 'old'),
#  ('Lolo', 'old'),
#  ('airport', 'old'),
#  ('visit', 'old'),
#  ('airport', 'old'),
#  ('boyfriend', 'old'),
#  ('funeral', 'old'),
#  ('year', 'old'),
#  ('nephew', 'unexpected'),
#  ('conditions', 'good'),
#  ('dinner', 'good'),
#  ('Lolo', 'good'),
#  ('idea', 'big'),
#  ('fan', 'frequent'),
#  ('downtown', 'frequent'),
#  ('Lolo', 'frequent'),
#  ('downtown', 'delicious'),
#  ('location', 'delicious'),
#  ('years', 'delicious'),
#  ('place', 'delicious'),
#  ('dinner', 'embarrassed'),
#  ('Lolo', 'true'),
#  ('airport', 'true'),
#  ('location', 'true'),
#  ('Lolo', 'green'),
#  ('tomatoes', 'disappointing'),
#  ('deal', 'fifteen'),
#  ('cheese', 'fifteen'),
#  ('grits', 'fifteen'),
#  ('banana', 'fifteen'),
#  ('pudding', 'fifteen'),
#  ('cashier', 'fifteen'),
#  ('Brittany', 'fifteen'),
#  ('minute', 'ready'),
#  ('wait', 'ready'),
#  ('food', 'ready'),
#  ('problem', 'ready'),
#  ('boyfriend', 'ready'),
#  ('flight', 'ready'),
#  ('minutes', 'ready'),
#  ('food', 'ready'),
#  ('children', 'sure'),
#  ('chicken', 'sure'),
#  ('tender', 'sure'),
#  ('baskets', 'sure'),
#  ('cashier', 'sure'),
#  ('receipt', 'other'),
#  ('food', 'other'),
#  ('order', 'other'),
#  ('minutes', 'other'),
#  ('food', 'great'),
#  ('one', 'great'),
#  ('minutes', 'great'),
#  ('chicken', 'great'),
#  ('tender', 'great'),
#  ('basket', 'great'),
#  ('chicken', 'great'),
#  ('waffles', 'soggy'),
#  ('Fries', 'soggy'),
#  ('chicken', 'soggy'),
#  ('tender', 'soggy'),
#  ('basket', 'soggy'),
#  ('cheese', 'runny'),
#  ('grits', 'runny'),
#  ('cheese', 'runny'),
#  ('soup', 'runny'),
#  ('sons', 'few'),
#  ('milk', 'few'),
#  ('bottle', 'few'),
#  ('MOLD', 'few'),
#  ('counter', 'few'),
#  ('Brittany', 'few'),
#  ('manager', 'few'),
#  ('minutes', 'moldy'),
#  ('manager', 'moldy'),
#  ('Bill', 'moldy'),
#  ('Bill', 'moldy'),
#  ('milk', 'interested'),
#  ('bottle', 'interested'),
#  ('drink', 'interested'),
#  ('point', 'interested'),
#  ('drink', 'total'),
#  ('concern', 'total'),
#  ('mold', 'total'),
#  ('milk', 'total'),
#  ('bottles', 'total'),
#  ('Bill', 'total'),
#  ('milk', 'total'),
#  ('bill', 'poor'),
#  ('subpar', 'poor'),
#  ('food', 'poor'),
#  ('service', 'poor'),
#  ('MOLDY', 'poor'),
#  ('milk', 'poor'),
#  ('Bill', 'poor'),
#  ('concern', 'poor'),
#  ('experience', 'common'),
#  ('concern', 'common'),
#  ('milk', 'common'),
#  ('bottles', 'common'),
#  ('mold', 'common'),
#  ('Bill', 'common'),
#  ('ink', 'common'),
#  ('mark', 'common'),
#  ('bottle', 'common'),
#  ('point', 'common'),
#  ('Bill', 'common'),
#  ('idiot', 'common'),
#  ('sense', 'hairy'),
#  ('mold', 'hairy'),
#  ('ink', 'close'),
#  ('mark', 'close'),
#  ('milks', 'sure'),
#  ('shelves', 'sure'),
#  ('Lolo', 'Super'),
#  ('food', 'Super'),
#  ('service', 'Super'),
#  ('location', 'Super'),
#  ('experience', 'great'),
#  ('boyfriend', 'great'),
#  ('times', 'disappointed'),
#  ('restaurant', 'perfect'),
#  ('Manti', 'perfect'),
#  ('price', 'perfect'),
#  ('point', 'perfect'),
#  ('Thick', 'limp'),
#  ('dough', 'limp'),
#  ('wisp', 'limp'),
#  ('ground', 'limp'),
#  ('lamb', 'limp'),
#  ('watery', 'limp'),
#  ('yogurt', 'deficient'),
#  ('sauce', 'deficient'),
#  ('spice', 'previous'),
#  ('aromatics', 'previous'),
#  ('incarnation', 'better'),
#  ('Anatalion', 'better'),
#  ('Turkish', 'better'),
#  ('Cuisine', 'better'),
#  ('bread', 'olive'),
#  ('start', 'olive'),
#  ('day', 'olive'),
#  ('leftovers', 'olive'),
#  ('day', 'olive'),
#  ('oil', 'fresh'),
#  ('appearance', 'fresh'),
#  ('meat', 'suspect'),
#  ('platter', 'suspect'),
#  ('ramekin', 'white'),
#  ('rice', 'white'),
#  ('Uncle', 'second'),
#  ('Ben', 'second'),
#  ('rice', 'second'),
#  ('ramekin', 'white'),
#  ('dollop', 'white'),
#  ('rice', 'tantamount'),
#  ('sprinkle', 'tantamount'),
#  ('parsley', 'tantamount'),
#  ('highway', 'particular'),
#  ('robbery', 'particular'),
#  ('restaurant', 'Turkish'),
#  ('Plaza', 'Turkish'),
#  ('point', 'Turkish'),
#  ('tea', 'insulting'),
#  ('place', 'nice'),
#  ('ambience', 'nice'),
#  ('layout', 'nice'),
#  ('place', 'Turkish'),
#  ('matter', 'Turkish'),
#  ('time', 'Turkish'),
#  ('Pasha', 'Turkish'),
#  ('Restaurant', 'Turkish'),
#  ('Heaven', 'Turkish'),
#  ('Downtown', 'Turkish'),
#  ('prices', 'Turkish'),
#  ('East', 'Turkish'),
#  ('York', 'Turkish'),
#  ('Thornecliffe', 'Turkish'),
#  ('location', 'Turkish'),
#  ('service', 'Turkish'),
#  ('product', 'Turkish'),
#  ('price', 'Turkish'),
#  ('Head', 'better'),
#  ('Shirin', 'better'),
#  ('Pizza', 'better'),
#  ('Pide', 'better'),
#  ('Mr', 'better'),
#  ('Pide', 'better'),
#  ('Kebab', 'better'),
#  ('pound', 'light'),
#  ('barbeque', 'light'),
#  ('pork', 'light'),
#  ('container', 'light'),
#  ('container', 'less'),
#  ('scale', 'less'),
#  ('ounces', 'Unacceptable'),
#  ('custom', 'facial'),
#  ('girl', 'professional'),
#  ('facial', 'professional'),
#  ('skin', 'professional'),
#  ('analysis', 'professional'),
#  ('website', 'long'),
#  ('question', 'long'),
#  ('skin', 'long'),
#  ('conditions', 'long'),
#  ('stuff', 'long'),
#  ('info', 'long'),
#  ('questions', 'long'),
#  ('cleansing', 'long'),
#  ('massage', 'good'),
#  ('face', 'weird'),
#  ('massage', 'weird'),
#  ('oil', 'weird'),
#  ('facial', 'good'),
#  ('attention', 'good'),
#  ('skin', 'good'),
#  ('minute', 'good'),
#  ('arm', 'good'),
#  ('beginning', 'good'),
#  ('one', 'different'),
#  ('things', 'whole'),
#  ('impression', 'whole'),
#  ('thing', 'amateur'),
#  ('like-', 'friendly'),
#  ('bucks', 'friendly'),
#  ('appointment', 'friendly'),
#  ('arm', 'friendly'),
#  ('injury', 'friendly'),
#  ('girl', 'friendly'),
#  ('Service', 'good'),
#  ('ambience', 'nice'),
#  ('Food', 'lousy'),
#  ('Way', 'salty'),
#  ('Capriotti', 'same'),
#  ('Shop', 'same'),
#  ('credit', 'same'),
#  ('card', 'same'),
#  ('purchase', 'same'),
#  ('employees', 'same'),
#  ('card', 'same'),
#  ('owner', 'same'),
#  ('store', 'same'),
#  ('card', 'same'),
#  ('number', 'same'),
#  ('months', 'same'),
#  ('day', 'upset'),
#  ('store', 'upset'),
#  ('charges', 'nasty'),
#  ('bank', 'nasty'),
#  ('money', 'nasty'),
#  ('principle', 'nasty'),
#  ('sweetheart', 'nasty'),
#  ('day', 'better'),
#  ('people', 'better'),
#  ('owners', 'better'),
#  ('employees', 'better'),
#  ('peoples', 'better'),
#  ('credit', 'better'),
#  ('card', 'better'),
#  ('numbers', 'better'),
#  ('worth', 'better'),
#  ('merchandise', 'better'),
#  ('sincerity', 'better'),
#  ('voice', 'better'),
#  ('attitude', 'better'),
#  ('disgust', 'better'),
#  ('fault', 'better'),
#  ('debit', 'better'),
#  ('card', 'better'),
#  ('apology', 'better'),
#  ('place', 'disturbing'),
#  ('fact', 'smaller'),
#  ('beef', 'smaller'),
#  ('curry', 'smaller'),
#  ('pancake', 'smaller'),
#  ('roti', 'smaller'),
#  ('piece', 'smaller'),
#  ('beef', 'smaller'),
#  ('bowl', 'smaller'),
#  ('cup', 'small'),
#  ('piece', 'insulting'),
#  ('pancake', 'insulting'),
#  ('place', 'potential'),
#  ('clientele', 'unwatchable'),
#  ('shows', 'unwatchable'),
#  ('time', 'large'),
#  ('groups', 'inebriated'),
#  ('guests', 'more'),
#  ('show', 'more'),
#  ('place', 'more'),
#  ('oil', 'extreme'),
#  ('tip', 'extreme'),
#  ('wash', 'worst'),
#  ('place', 'worst'),
#  ('AZ', 'only'),
#  ('hour', 'only'),
#  ('minutes', 'only'),
#  ('car', 'better'),
#  ('lube', 'better'),
#  ('Car', 'better'),
#  ('wash', 'better'),
#  ('trash', 'better'),
#  ('kid', 'better'),
#  ('Yelp', 'new'),
#  ('miles', 'new'),
#  ('website', 'new'),
#  ('worth', 'new'),
#  ('food', 'new'),
#  ('cart', 'new'),
#  ('card', 'new'),
#  ('#', 'new'),
#  ('card', 'new'),
#  ('order', 'new'),
#  ('bank', 'new'),
#  ('card', 'new'),
#  ('phone', 'new'),
#  ('Senior', 'new'),
#  ('Account', 'new'),
#  ('Executive', 'new'),
#  ('customers', 'poor'),
#  ('month', 'poor'),
#  ('Merchant', 'poor'),
#  ('Accounts', 'poor'),
#  ('business', 'poor'),
#  ('orders', 'poor'),
#  ('Freddy', 'nice'),
#  ('food', 'nice'),
#  ('tonight', 'nice'),
#  ('Monday', 'nice'),
#  ('oct', 'nice'),
#  ('drive', 'nice'),
#  ('girlfriend', 'nice'),
#  ('cream', 'nice'),
#  ('concrete', 'nice'),
#  ('window', 'nice'),
#  ('mins', 'nice'),
#  ('girlfriend', 'nice'),
#  ('concrete', 'nice'),
#  ('cream', 'nice'),
#  ('cherry', 'nice'),
#  ('paper', 'fast'),
#  ('food', 'difficult'),
#  ('food', 'kinda'),
#  ('orders', 'kinda'),
#  ('non', 'kinda'),
#  ('-', 'kinda'),
#  ('edibles', 'kinda'),
#  ('food', 'kinda'),
#  ('must', 'Needless'),
#  ('lunch', 'dead'),
#  ('friend', 'dead'),
#  ('table', 'dead'),
#  ('fly', 'dead'),
#  ('plate', 'dead'),
#  ('waiter', 'dead'),
#  ('plate', 'dead'),
#  ('fly', 'dead'),
#  ('floor', 'dead'),
#  ('plate', 'dead'),
#  ('fly', 'Poor'),
#  ('server', 'Poor'),
#  ('plate', 'Poor'),
#  ('restaurant', 'Poor'),
#  ('service', 'poor'),
#  ('Kost', 'first'),
#  ('stars', 'first'),
#  ('choice', 'first'),
#  ('time', 'extreme'),
#  ('reservation', 'extreme'),
#  ('birthday', 'extreme'),
#  ('brunch', 'extreme'),
#  ('Sunday', 'extreme'),
#  ('pm', 'extreme'),
#  ('people', 'extreme'),
#  ('husband', 'extreme'),
#  ('am', 'extreme'),
#  ('day', 'extreme'),
#  ('reservation', 'extreme'),
#  ('city', 'extreme'),
#  ('Toronto', 'extreme'),
#  ('ice', 'extreme'),
#  ('storm', 'extreme'),
#  ('storm', 'less'),
#  ('house', 'less'),
#  ('manager', 'less'),
#  ('credit', 'less'),
#  ('card', 'less'),
#  ('person', 'less'),
#  ('hours', 'safe'),
#  ('mother', 'safe'),
#  ('nature', 'safe'),
#  ('side', 'safe'),
#  ('roads', 'unsafe'),
#  ('cancellation', 'unsafe'),
#  ('policy', 'unsafe'),
#  ('understanding', 'unsafe'),
#  ('weather', 'last'),
#  ('conditions', 'last'),
#  ('hands', 'last'),
#  ('Today', 'last'),
#  ('family', 'last'),
#  ('minute', 'mean'),
#  ('reservation', 'mean'),
#  ('lunch', 'mean'),
#  ('Kost', 'mean'),
#  ('.', 'mean'),
#  ('restroom', 'mean'),
#  ('time', 'good'),
#  ('guests', 'good'),
#  ('table', 'good'),
#  ('minutes', 'full'),
#  ('table', 'full'),
#  ('waitress', 'full'),
#  ('table', 'full'),
#  ('minutes', 'full'),
#  ('server', 'full'),
#  ('favour', 'full'),
#  ('food', 'full'),
#  ('favours', 'full'),
#  ('way', 'full'),
#  ('manager', 'full'),
#  ('food', 'full'),
#  ('mouth', 'full'),
#  ('lack', 'other'),
#  ('service', 'other'),
#  ('servers', 'good'),
#  ('meals', 'good'),
#  ('Kost', 'good'),
#  ('Bisha', 'good'),
#  ('breaks', 'good'),
#  ('areas', 'good'),
#  ('staff', 'good'),
#  ('experiences', 'good'),
#  ('friend', 'good'),
#  ('food', 'great'),
#  ('service', 'cool'),
#  ('coffee', 'busy'),
#  ('service', 'busy'),
#  ('saturday', 'extra'),
#  ('afternoon', 'extra'),
#  ('5min', 'extra'),
#  ('coffee', 'extra'),
#  ('ice', 'long'),
#  ('10min', 'iced'),
#  ('coffee', 'ready'),
#  ('lady', 'iced'),
#  ('latte', 'forgot'),
#  ('order', 'ready'),
#  ('customer', 'annoying'),
#  ('drink', 'annoying'),
#  ('customer', 'annoying'),
#  ('coffee', 'sloppy'),
#  ('way', 'regulr'),
#  ('lid', 'regulr'),
#  ('cup', 'regulr'),
#  ('year', 'rude'),
#  ('people', 'disappointing'),
#  ('mistake', 'disappointing'),
#  ('problem', 'disappointing'),
#  ('coffee', 'disappointing'),
#  ('taste', 'disappointing'),
#  ('ice', 'sure'),
#  ('longshot', 'sure'),
#  ('milk', 'sure'),
#  ('color', 'sure'),
#  ('people', 'sure'),
#  ('place', 'sure'),
#  ('weekend', 'good'),
#  ('lunch', 'good'),
#  ('time', 'good'),
#  ('service', 'hyped'),
#  ('coffee', 'hyped'),
#  ('place', 'hyped'),
#  ('food', 'gross'),
#  ('service', 'worse'),
#  ('experience', 'ridiculous'),
#  ('customer', 'ridiculous'),
#  ('service', 'ridiculous'),
#  ('joke', 'initial'),
#  ('menu', 'initial'),
#  ('majority', 'initial'),
#  ('food', 'initial'),
#  ('server', 'initial'),
#  ('chef', 'initial'),
#  ('order', 'initial'),
#  ('list', 'initial'),
#  ('list', 'initial'),
#  ('hours', 'initial'),
#  ('order', 'low'),
#  ('wait', 'low'),
#  ('appetite', 'low'),
#  ('sushi', 'low'),
#  ('quality', 'aware'),
#  ('prince', 'aware'),
#  ('experience', 'aware'),
#  ('WAY', 'better'),
#  ('DOWNHILL', 'better'),
#  ('time', 'better'),
#  ('money', 'better'),
#  ('Heart', 'better'),
#  ('sushi', 'better'),
#  ('food', 'horrible'),
#  ('customer', 'horrible'),
#  ('service', 'horrible'),
#  ('way', 'horrible'),
#  ('food', 'better'),
#  ('food', 'least'),
#  ('one', 'least'),
#  ('BS', 'alternative'),
#  ('Eastern', 'Worst'),
#  ('Medicines', 'Worst'),
#  ('girl', 'total'),
#  ('front', 'total'),
#  ('bath', 'total'),
#  ('attitude', 'excellent'),
#  ('friend', 'excellent'),
#  ('I.', 'excellent'),
#  ('places', 'excellent'),
#  ('reason', 'excellent'),
#  ('Groupon', 'excellent'),
#  ('customers', 'excellent'),
#  ('door', 'excellent'),
#  ('experience', 'additiinal'),
#  ('Groupon', 'additiinal'),
#  ('money', 'fine'),
#  ('print', 'sorry'),
#  ('NoDa', 'next'),
#  ('week', 'next'),
#  ('Dog', 'next'),
#  ('Bar', 'next'),
#  ('parking', 'next'),
#  ('lot', 'next'),
#  ('dog', 'next'),
#  ('bar', 'next'),
#  ('bar', 'next'),
#  ('door', 'entire'),
#  ('parking', 'other'),
#  ('lot', 'other'),
#  ('mess', 'other'),
#  ('people', 'other'),
#  ('cars', 'other'),
#  ('spots', 'other'),
#  ('dozen', 'other'),
#  ('cars', 'marked'),
#  ('note', 'marked'),
#  ('spots', 'international'),
#  ('train', 'international'),
#  ('tracks', 'international'),
#  ('towing', 'plastic'),
#  ('signs', 'plastic'),
#  ('dog', 'plastic'),
#  ('urine', 'plastic'),
#  ('astroturf', 'terrible'),
#  ('idea', 'fine'),
#  ('area', 'fine'),
#  ('rain', 'fine'),
#  ('dog', 'fine'),
#  ('urine', 'fine'),
#  ('car', 'obscure'),
#  ('parking', 'obscure'),
#  ('lot', 'obscure'),
#  ('sign', 'blind'),
#  ('words', 'blind'),
#  ('dog', 'blind'),
#  ('bar', 'blind'),
#  ('pig', 'confused'),
#  ('bar', 'confused'),
#  ('customer', 'confused'),
#  ('towing', 'close'),
#  ('sign', 'close'),
#  ('symbol', 'close'),
#  ('company', 'close'),
#  ('car', 'close'),
#  ('track', 'ironic'),
#  ('sign', 'same'),
#  ('train', 'same'),
#  ('tracks', 'same'),
#  ('distance', 'same'),
#  ('bar', 'same'),
#  ('bartender', 'same'),
#  ('spots', 'same'),
#  ('cars', 'same'),
#  ('people', 'same'),
#  ('spots', 'same'),
#  ('cars', 'frustrated'),
#  ('spots', 'frustrated'),
#  ('Dog', 'close'),
#  ('response', 'close'),
#  ('people', 'close'),
#  ('tracks', 'few'),
#  ('sign', 'few'),
#  ('areas', 'much'),
#  ('cement', 'much'),
#  ('block', 'much'),
#  ('area', 'closer'),
#  ('people', 'closer'),
#  ('cars', 'international'),
#  ('track', 'international'),
#  ('tow', 'Needless'),
#  ('sign', 'Needless'),
#  ('NoDa', 'extra'),
#  ('minutes', 'amazing'),
#  ('Lucky', 'amazing'),
#  ('Dog', 'amazing'),
#  ('Bark', 'amazing'),
#  ('Brew', 'amazing'),
#  ('parking', 'amazing'),
#  ('spots', 'amazing'),
#  ('top', 'amazing'),
#  ('facility', 'amazing'),
#  ('AstroTurf', 'unclear'),
#  ('place', 'unclear'),
#  ('parking', 'unclear'),
#  ('inconvenience', 'unclear'),
#  ('reason', 'ridiculous'),
#  ('place', 'ridiculous'),
#  ('dump', 'ridiculous'),
#  ('tow', 'ridiculous'),
#  ('fee', 'ridiculous'),
#  ('people', 'worth'),
#  ('place', 'worth'),
#  ('Embassy', 'bad'),
#  ('Suites', 'bad'),
#  ('reviews', 'bad'),
#  ('experience', 'uneasy'),
#  ('Embassy', 'uneasy'),
#  ('Suites', 'uneasy'),
#  ('name', 'uneasy'),
#  ('area', 'dirty'),
#  ('hotel', 'dirty'),
#  ('cleaning', 'ugh'),
#  ('surface', 'ugh'),
#  ('level', 'ugh'),
#  ('furniture', 'ugh'),
#  ('elevators', 'ugh'),
#  ('hallways', 'ugh'),
#  ('blanket', 'bad'),
#  ('room', 'bad'),
#  ('odor', 'new'),
#  ('blanket', 'nasty'),
#  ('girl', 'nasty'),
#  ('attitude', 'wrong'),
#  ('one', 'new'),
#  ('husband', 'new'),
#  ('IT', 'new'),
#  ('blanket', 'good'),
#  ('breakfast', 'good'),
#  ('dining', 'clean'),
#  ('area', 'clean'),
#  ('Food', 'ghetto'),
#  ('floor', 'ghetto'),
#  ('place', 'ghetto'),
#  ('club', 'unsavory'),
#  ('street', 'unsavory'),
#  ('place', 'unsavory'),
#  ('locals', 'unsavory'),
#  ('night', 'unsavory'),
#  ('partying', 'unsavory'),
#  ('characters', 'due'),
#  ('place', 'due'),
#  ('gunshots', 'due'),
#  ('area', 'due'),
#  ('Charlotte', 'due'),
#  ('hotel', 'due'),
#  ('name', 'disappointed'),
#  ('hilton', 'disappointed'),
#  ('honors', 'disappointed'),
#  ('member', 'disappointed'),
#  ('October', 'pregnant'),
#  ('family', 'pregnant'),
#  ('Outback', 'pregnant'),
#  ('Chandler', 'pregnant'),
#  ('AZ', 'pregnant'),
#  ('months', 'pregnant'),
#  ('medication', 'pregnant'),
#  ('daiquiri', 'first'),
#  ('husband', 'first'),
#  ('sips', 'right'),
#  ('drink', 'corporate'),
#  ...]

# %% [markdown]
# #### Find the top 10 most frequent noun-adjective pairs

# %%
counter=collections.Counter(noun_adj_pairs)
print(counter.most_common(10))
# Out:
# [(('day', 'next'), 4), (('card', 'same'), 3), (('card', 'new'), 3), (('plate', 'dead'), 3), (('bar', 'pissed'), 3), (('waffle', 'blacker'), 3), (('chicken', 'orange'), 2), (('place', 'dirty'), 2), (('place', 'first'), 2), (('people', 'safe'), 2)]

# %% [markdown]
# ## 4 star ratings
# #### Randomly select 50 reviews from different businesses with rating 4

# %%
# Filter reviews with 4 star and store in a dataframe
fourStar = data[data['stars']==4]

# Group by business ID and sample a random 4-star review from each group (1 per business)
grouped = oneStar.groupby('business_id').sample(n=1)

# Randomly select 50 reviews of rating 4 (one from each business)
random50 = grouped.sample(n=50)

# %% [markdown]
# #### Extract all noun-adjective pairs

# %%
nlp = spacy.load('en_core_web_sm')
noun_adj_pairs = []

for i in random50['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((str(token),str(doc[j])))
              break
noun_adj_pairs
# Out:
# [('issue', 'same'),
#  ('response', 'same'),
#  ('deductible', 'same'),
#  ('lines', 'same'),
#  ('issue', 'same'),
#  ('things', 'same'),
#  ('car', 'same'),
#  ('time', 'same'),
#  ('day', 'awhile'),
#  ('time', 'awhile'),
#  ('service', 'awhile'),
#  ('tech', 'awhile'),
#  ('care', 'awhile'),
#  ('account', 'awhile'),
#  ('course', 'awhile'),
#  ('family', 'few'),
#  ('health', 'few'),
#  ('issue', 'few'),
#  ('work', 'few'),
#  ('months', 'least'),
#  ('headache', 'first'),
#  ('time', 'first'),
#  ('end', 'first'),
#  ('issue', 'first'),
#  ('shop', 'first'),
#  ('repairs', 'first'),
#  ('place', 'thankful'),
#  ('times', 'last'),
#  ('months', 'average'),
#  ('weekends', 'average'),
#  ('party', 'great'),
#  ('time', 'extensive'),
#  ('menu', 'extensive'),
#  ('options', 'nice'),
#  ('basics', 'nice'),
#  ('fish', 'nice'),
#  ('lovers', 'nice'),
#  ('soups', 'typical'),
#  ('tempura', 'tremendous'),
#  ('meat', 'tremendous'),
#  ('dishes', 'tremendous'),
#  ('lunch', 'tremendous'),
#  ('price', 'tremendous'),
#  ('AYCE', 'tremendous'),
#  ('value', 'concerned'),
#  ('sushi', 'concerned'),
#  ('items', 'large'),
#  ('Tuna', 'large'),
#  ('sashimi', 'large'),
#  ('lot', 'large'),
#  ('sashimi', 'large'),
#  ('matter', 'large'),
#  ('shrimp', 'realistic'),
#  ('nigiri', 'realistic'),
#  ('shrimp', 'nice'),
#  ('tuna', 'nice'),
#  ('eel', 'nice'),
#  ('makis', 'nice'),
#  ('lot', 'nice'),
#  ('AYCE', 'nice'),
#  ('course', 'nice'),
#  ('eel', 'nice'),
#  ('dinner', 'nice'),
#  ('price', 'nice'),
#  ('course', 'nice'),
#  ('selection', 'nice'),
#  ('lunch', 'low'),
#  ('Aji', 'low'),
#  ('Sai', 'low'),
#  ('end', 'wise'),
#  ('price', 'wise'),
#  ('sushi', 'full'),
#  ('totem', 'full'),
#  ('pole', 'full'),
#  ('Generation', 'full'),
#  ('Sushi', 'full'),
#  ('Sushi', 'full'),
#  ('Bloor', 'full'),
#  ('meh', 'full'),
#  ('bit', 'full'),
#  ('one', 'full'),
#  ('place', 'full'),
#  ('cuisine', 'tasty'),
#  ('simile', 'worth'),
#  ('value', 'authentic'),
#  ('fraction', 'authentic'),
#  ('restaurant', 'simple'),
#  ('minutes', 'simple'),
#  ('Yonge', 'simple'),
#  ('Bloor', 'simple'),
#  ('decor', 'simple'),
#  ('service', 'good'),
#  ('way', 'different'),
#  ('bit', 'different'),
#  ('lot', 'different'),
#  ('restaurants', 'Japanese'),
#  ('language', 'Japanese'),
#  ('barrier', 'Japanese'),
#  ('servers', 'Japanese'),
#  ('place', 'Japanese'),
#  ('Chinese', 'Japanese'),
#  ('time', 'happy'),
#  ('selection', 'big'),
#  ('beers', 'big'),
#  ('pretzel', 'ginormous'),
#  ('shrimp', 'good'),
#  ('cocktail', 'good'),
#  ('size', 'perfect'),
#  ('shrimp', 'perfect'),
#  ('cocktail', 'perfect'),
#  ('sauce', 'perfect'),
#  ('amount', 'perfect'),
#  ('horseradish', 'perfect'),
#  ('chicken', 'perfect'),
#  ('wings', 'perfect'),
#  ('amount', 'awesome'),
#  ('heat', 'awesome'),
#  ('server', 'awesome'),
#  ('Joany', 'awesome'),
#  ('tomorrow', 'good'),
#  ('fish', 'good'),
#  ('chips', 'good'),
#  ('Wings', 'good'),
#  ('burgers', 'good'),
#  ('Susan', 'Vietnamese'),
#  ('C', 'Vietnamese'),
#  ('review', 'Vietnamese'),
#  ('fact', 'Vietnamese'),
#  ('White', 'Vietnamese'),
#  ('People', 'Vietnamese'),
#  ('seal', 'Vietnamese'),
#  ('approval', 'Vietnamese'),
#  ('Nem', 'Vietnamese'),
#  ('Nuong', 'Vietnamese'),
#  ('pork', 'serious'),
#  ('sausage', 'serious'),
#  ('DIY', 'other'),
#  ('veg', 'other'),
#  ('stuff', 'decent'),
#  ('goodness', 'decent'),
#  ('rice', 'decent'),
#  ('paper', 'decent'),
#  ('roll', 'decent'),
#  ('sausage', 'decent'),
#  ('inhale', 'decent'),
#  ('mouth', 'decent'),
#  ('Fantastic', 'decent'),
#  ('Pho', 'decent'),
#  ('Banh', 'tough'),
#  ('beo', 'tough'),
#  ('sit', 'better'),
#  ('restaurants', 'better'),
#  ('disappointment', 'better'),
#  ('street', 'bad'),
#  ('Jim', 'great'),
#  ('guys', 'great'),
#  ('shop', 'great'),
#  ('job', 'defective'),
#  ('work', 'defective'),
#  ('part', 'defective'),
#  ('sedan', 'notorious'),
#  ('problems', 'bad'),
#  ('lot', 'bad'),
#  ('money', 'bad'),
#  ('car', 'bad'),
#  ('issues', 'bad'),
#  ('work', 'bad'),
#  ('parts', 'bad'),
#  ('coolant', 'bad'),
#  ('tank', 'bad'),
#  ('sensor', 'bad'),
#  ('times', 'few'),
#  ('span', 'few'),
#  ('months', 'free'),
#  ('issues', 'free'),
#  ('charges', 'free'),
#  ('charge', 'important'),
#  ('things', 'expensive'),
#  ('auto', 'cost'),
#  ('shop', 'cost'),
#  ('work', 'cost'),
#  ('Thanks', 'good'),
#  ('customer', 'reasonable'),
#  ('service', 'reasonable'),
#  ('price.fast', 'efficient'),
#  ('service', 'cool'),
#  ('quality', 'cool'),
#  ('job', 'cool'),
#  ('car', 'cool'),
#  ('quality', 'best'),
#  ('film', 'best'),
#  ('place', 'long'),
#  ('time', 'happy'),
#  ('way', 'tangy'),
#  ('house', 'tangy'),
#  ('salad', 'tangy'),
#  ('ginger', 'tangy'),
#  ('dressing', 'tangy'),
#  ('dressing', 'tangy'),
#  ('house', 'tangy'),
#  ('citrusy', 'good'),
#  ('radish', 'nice'),
#  ('roll', 'nice'),
#  ('surprise', 'different'),
#  ('rolls', 'good'),
#  ('service', 'best'),
#  ('part', 'previous'),
#  ('ways', 'previous'),
#  ('go', 'refreshing'),
#  ('sushi', 'refreshing'),
#  ('bar', 'refreshing'),
#  ('service', 'refreshing'),
#  ('decline', 'refreshing'),
#  ('surprise', 'sure'),
#  ('Congee', 'clean'),
#  ('Queen', 'clean'),
#  ('design', 'complete'),
#  ('drawings', 'traditional'),
#  ('women', 'traditional'),
#  ('dress', 'fresh'),
#  ('tank', 'fresh'),
#  ('fish', 'alone'),
#  ('display', 'alone'),
#  ('BBQ', 'alone'),
#  ('meats', 'alone'),
#  ('portions', 'generous'),
#  ('lot', 'hot'),
#  ('menu', 'hot'),
#  ('items', 'hot'),
#  ('soup', 'good'),
#  ('seafood', 'good'),
#  ('noodles', 'good'),
#  ('dish', 'good'),
#  ('restaurant', 'regular'),
#  ('chè', 'soft'),
#  ('San', 'soft'),
#  ('Jose', 'soft'),
#  ('franchise', 'soft'),
#  ('today', 'soft'),
#  ('opening', 'refreshing'),
#  ('Ginger', 'refreshing'),
#  ('O.', 'refreshing'),
#  ('check', 'refreshing'),
#  ('in', 'refreshing'),
#  ('Lychee', 'refreshing'),
#  ('Jello', 'refreshing'),
#  ('Bambu', 'refreshing'),
#  ('Favorite', 'refreshing'),
#  ('dessert', 'warm'),
#  ('Sunday', 'excited'),
#  ('desserts', 'excited'),
#  ('tax', 'excited'),
#  ('Bambu', 'open'),
#  ('months', 'small'),
#  ('storefront', 'small'),
#  ('seating', 'limited'),
#  ('tables', 'nice'),
#  ('days', 'likely'),
#  ('car', 'likely'),
#  ('oil', 'likely'),
#  ('change', 'likely'),
#  ('need', 'likely'),
#  ('guy', 'likely'),
#  ('desk', 'likely'),
#  ('appointment', 'likely'),
#  ('book', 'likely'),
#  ('minutes', 'likely'),
#  ('car', 'likely'),
#  ('oil', 'likely'),
#  ('change', 'likely'),
#  ('company', 'good'),
#  ('lunch', 'good'),
#  ('restaurant', 'good'),
#  ('food', 'good'),
#  ('bar', 'upscale'),
#  ('center', 'upscale'),
#  ('casino', 'upscale'),
#  ('MGM', 'upscale'),
#  ('Grand', 'upscale'),
#  ('bit', 'upscale'),
#  ('version', 'white'),
#  ('Coyote', 'white'),
#  ('Ugly', 'white'),
#  ('bar', 'white'),
#  ('whores', 'white'),
#  ('trash', 'reasonable'),
#  ('bartenders', 'reasonable'),
#  ('bar', 'reasonable'),
#  ('outfits', 'reasonable'),
#  ('drinks', 'reasonable'),
#  ('Vegas', 'strong'),
#  ('prices', 'strong'),
#  ('restaurants', 'most'),
#  ('Pittsburgh', 'most'),
#  ('Koreans', 'Korean'),
#  ('Pittsburgh', 'Korean'),
#  ('food', 'little'),
#  ('food', 'little'),
#  ('bit', 'expensive'),
#  ('pricy', 'expensive'),
#  ('Green', 'authentic'),
#  ('Pepper', 'authentic'),
#  ('Oiishi', 'Korean'),
#  ('Bento', 'Korean'),
#  ('Koreans', 'international'),
#  ('friends', 'private'),
#  ('favorite', 'private'),
#  ('seafood', 'private'),
#  ('pancake', 'private'),
#  ('bibimpap', 'private'),
#  ('rice', 'private'),
#  ('bottom', 'private'),
#  ('Karaoke', 'private'),
#  ('rooms', 'private'),
#  ('room', 'pricey'),
#  ('range', 'Korean'),
#  ('songs', 'mainstream'),
#  ('courtyard', 'warm'),
#  ('fall', 'Folky'),
#  ('evening', 'Folky'),
#  ('band', 'perfect'),
#  ('accompaniment', 'Reasonable'),
#  ('setting', 'Reasonable'),
#  ('food', 'Reasonable'),
#  ('tap', 'attentive'),
#  ('selection', 'attentive'),
#  ('Service', 'attentive'),
#  ('water', 'full'),
#  ('glasses', 'full'),
#  ('menu', 'large'),
#  ('questions', 'large'),
#  ('ease', 'large'),
#  ('biscuit', 'large'),
#  ('inside', 'delightful'),
#  ('balance', 'sweet'),
#  ('field', 'delicious'),
#  ('pea', 'delicious'),
#  ('salad', 'delicious'),
#  ('bacon', 'hearty'),
#  ('lots', 'hearty'),
#  ('farmer', 'hearty'),
#  ('cheese', 'hearty'),
#  ('kale', 'hearty'),
#  ('peas', 'hearty'),
#  ('meal', 'bland'),
#  ('buttermilk', 'bland'),
#  ('pie', 'bland'),
#  ('lemon', 'bland'),
#  ('curd', 'bland'),
#  ('bit', 'bland'),
#  ('crust', 'heavy'),
#  ('curd', 'thin'),
#  ('Bathrooms', 'clean'),
#  ('signage', 'multiple'),
#  ('patrons', 'multiple'),
#  ('establishments', 'same'),
#  ('Service', 'better'),
#  ('food', 'better'),
#  ('way', 'better'),
#  ('Phoenix', 'delicious'),
#  ('Food', 'delicious'),
#  ('food', 'best'),
#  ('Congee', 'best'),
#  ('Queen', 'best'),
#  ('Phoenix', 'best'),
#  ('bbq', 'best'),
#  ('duck', 'best'),
#  ('Food', 'good'),
#  ('beer', 'cold'),
#  ('Jessica', 'available'),
#  ('server', 'available'),
#  ('store', 'bloody'),
#  ('Venetian', 'bloody'),
#  ('window', 'bloody'),
#  ('display', 'bloody'),
#  ('work', 'bloody'),
#  ('love', 'bloody'),
#  ('shoes', 'Great'),
#  ('size', 'Great'),
#  ('mall', 'Great'),
#  ('strip', 'Great'),
#  ('dinner', 'tasty'),
#  ('tonight', 'tasty'),
#  ('lettuce', 'tasty'),
#  ('wraps', 'tasty'),
#  ('entrees', 'tasty'),
#  ('chicken', 'tasty'),
#  ('sandwich', 'tasty'),
#  ('Mayworth', 'tasty'),
#  ('style', 'tasty'),
#  ('friend', 'tasty'),
#  ('chicken', 'tasty'),
#  ('salad', 'tasty'),
#  ('Lots', 'tasty'),
#  ('options', 'customizable'),
#  ('sandwiches', 'customizable'),
#  ('thrill', 'great'),
#  ('dessert', 'great'),
#  ('eatery', 'great'),
#  ('desserts', 'great'),
#  ('Queens', 'great'),
#  ('City', 'great'),
#  ('Pastry', 'great'),
#  ('pub', 'great'),
#  ('beer', 'great'),
#  ('menu', 'great'),
#  ('food', 'friendly'),
#  ('service', 'friendly'),
#  ('food', 'good'),
#  ('atmosphere', 'sure'),
#  ('florist', 'Beautiful'),
#  ('arrangements', 'several'),
#  ('times', 'good'),
#  ('prices', 'good'),
#  ('service', 'excellent'),
#  ('florist', 'friendly'),
#  ('flowers', 'friendly'),
#  ('place', 'friendly'),
#  ('Owner', 'friendly'),
#  ('place', 'honest'),
#  ('review', 'less'),
#  ('times', 'less'),
#  ('orders', 'less'),
#  ('customer', 'small'),
#  ('service', 'small'),
#  ('interactions', 'small'),
#  ('times', 'small'),
#  ('order', 'small'),
#  ('food', 'small'),
#  ('place', 'small'),
#  ('hours', 'happy'),
#  ('hour', 'sushi'),
#  ('day', 'sushi'),
#  ('orders', 'sushi'),
#  ('menu', 'sushi'),
#  ('sushi', 'sushi'),
#  ('soup', 'sushi'),
#  ('salad', 'sushi'),
#  ('miso', 'sushi'),
#  ('soup', 'sushi'),
#  ('times', 'sushi'),
#  ('rolls', 'full'),
#  ('rolls', 'spicy'),
#  ('menu', 'spicy'),
#  ('salmon', 'spicy'),
#  ('tuna', 'spicy'),
#  ('Hawaii', 'spicy'),
#  ('roll', 'spicy'),
#  ('rolls', 'typical'),
#  ('restaurant', 'deluxe'),
#  ('Hawaii', 'deluxe'),
#  ('roll', 'deluxe'),
#  ('sauce', 'sushi'),
#  ('roll', 'sushi'),
#  ('favorite', 'sushi'),
#  ('messes', 'sushi'),
#  ('taste', 'fair'),
#  ('prices', 'fair'),
#  ('sushi', 'cooked'),
#  ('sushi', 'cheap'),
#  ('time', 'cheap'),
#  ('time', 'cheap'),
#  ('tasty', 'cheap'),
#  ('place', 'good'),
#  ('service', 'misleading'),
#  ('name', 'misleading'),
#  ('honest-', 'Greek'),
#  ('Cajun', 'good'),
#  ('time', 'Good'),
#  ('beer', 'next'),
#  ('selection', 'next'),
#  ('food', 'next'),
#  ('steak', 'classic'),
#  ('houses', 'classic'),
#  ('steak', 'classic'),
#  ('steak', 'few'),
#  ('house', 'few'),
#  ('experience', 'few'),
#  ('favourites', 'grand'),
#  ('Toronto', 'grand'),
#  ('restaurant', 'grand'),
#  ('landscape', 'grand'),
#  ('north', 'grand'),
#  ('end', 'grand'),
#  ('Toronto', 'grand'),
#  ('Thornhill', 'grand'),
#  ('staple', 'grand'),
#  ('Octagon', 'grand'),
#  ('Restaurant', 'grand'),
#  ('fire', 'grand'),
#  ('ground', 'grand'),
#  ('fireplace', 'grand'),
#  ('renovation', 'original'),
#  ('belle', 'Rich'),
#  ('époque', 'Rich'),
#  ('iron', 'Rich'),
#  ('doorway', 'Rich'),
#  ('carat', 'Rich'),
#  ('gold', 'Rich'),
#  ('St.', 'Rich'),
#  ('Regis', 'Rich'),
#  ('Hotel', 'Rich'),
#  ('New', 'Rich'),
#  ('York', 'Rich'),
#  ('décor', '18th'),
#  ('century', 'Belgian'),
#  ('glass', 'Belgian'),
#  ('panels', 'Belgian'),
#  ('Church', 'European'),
#  ('oil', 'walnut'),
#  ('paintings', 'walnut'),
#  ('Mahogany', 'walnut'),
#  ('wood', 'intricate'),
#  ('paneling', 'intricate'),
#  ('carvings', 'Tiffany'),
#  ('custom', 'Tiffany'),
#  ('lamps', 'requisite'),
#  ('chandeliers', 'requisite'),
#  ('brass', 'requisite'),
#  ('wall', 'requisite'),
#  ('leather', 'requisite'),
#  ('banquets', 'requisite'),
#  ('grandeur', 'Victorian'),
#  ('style', 'Prepared'),
#  ('jewel', 'Prepared'),
#  ('box', 'Prepared'),
#  ('Dress', 'Prepared'),
#  ('code', 'Prepared'),
#  ('business', 'Prepared'),
#  ('casual', 'Prepared'),
#  ('room', 'Prepared'),
#  ('presentation', 'Prepared'),
#  ('ambience', 'Prepared'),
#  ('plating', 'Prepared'),
#  ('food', 'Prepared'),
#  ('table', 'crisp'),
#  ('side', 'crisp'),
#  ('Caesar', 'crisp'),
#  ('salad', 'crisp'),
#  ('romaine', 'creamy'),
#  ('y', 'crunchy'),
#  ('bacon', 'crunchy'),
#  ('croutons', 'proud'),
#  ('Caesar', 'proud'),
#  ('scampi', 'colossal'),
#  ('Shrimp', 'colossal'),
#  ('cocktail', 'colossal'),
#  ('meaty', 'smoky'),
#  ('shrimp', 'smoky'),
#  ('iceberg', 'smoky'),
#  ('lettuce', 'smoky'),
#  ('tangy', 'smoky'),
#  ('house', 'smoky'),
#  ('cocktail', 'smoky'),
#  ('sauce', 'smoky'),
#  ('Lip', 'smoky'),
#  ('smacking', 'smoky'),
#  ('baby', 'smoky'),
#  ('ribs', 'smoky'),
#  ('charcoal', 'smoky'),
#  ('essence', 'zesty'),
#  ('barbeque', 'Good'),
#  ('sauce', 'Good'),
#  ('thing', 'ample'),
#  ('finger', 'ample'),
#  ('bowls', 'ample'),
#  ('hands', 'ample'),
#  ('portion', 'ready'),
#  ('wine', 'ready'),
#  ('cellar', 'ready'),
#  ('menu', 'ready'),
#  ('appetizers', 'ready'),
#  ('appetites', 'ready'),
#  ('charcoal', 'ready'),
#  ('steaks', 'ready'),
#  ('ounce', 'juicy'),
#  ('rib', 'juicy'),
#  ('eye', 'juicy'),
#  ('Sizzling', 'juicy'),
#  ('corn', 'garnish'),
#  ('beef', 'garnish'),
#  ('packs', 'garnish'),
#  ('flavour', 'garnish'),
#  ('sauce', 'garnish'),
#  ('taste', 'Quality'),
#  ('buds', 'Quality'),
#  ('meat', 'attentive'),
#  ('care', 'attentive'),
#  ('consistency', 'attentive'),
#  ('Octagon', 'attentive'),
#  ('longevity', 'attentive'),
#  ('mouthwatering', 'attentive'),
#  ('bite', 'attentive'),
#  ('conversation', 'attentive'),
#  ('waiter', 'Rich'),
#  ('glasses', 'Rich'),
#  ('dessert', 'Rich'),
#  ('coconut', 'soft'),
#  ('cream', 'soft'),
#  ('pie', 'soft'),
#  ('crust', 'pecan'),
#  ('mini', 'pecan'),
#  ('pie', 'warm'),
#  ('cocoa', 'warm'),
#  ('chocolate', 'warm'),
#  ('sauce', 'warm'),
#  ('Octagon', 'warm'),
#  ('mode', 'lush'),
#  ('sweets', 'decadent'),
#  ('service', 'happy'),
#  ('manager', 'happy'),
#  ('hour', 'best'),
#  ('hubby', 'best'),
#  ('hornets', 'best'),
#  ('game', 'best'),
#  ('breakfast', 'best'),
#  ('breakfast', 'friendly'),
#  ('staff', 'friendly'),
#  ('desk', 'rude'),
#  ('bar', 'rude'),
#  ('hotel', 'rude'),
#  ('incident', 'unlocked'),
#  ('room', 'unlocked'),
#  ('door', 'unlocked'),
#  ('day', 'strange'),
#  ('place', 'strange'),
#  ('keys', 'strange'),
#  ('morning', 'sure'),
#  ('room', 'double'),
#  ('friends', 'huge'),
#  ('dinner', 'huge'),
#  ('week', 'huge'),
#  ('portions', 'huge'),
#  ('pasta', 'yummy'),
#  ('bolognaise', 'yummy'),
#  ('sauce', 'yummy'),
#  ('day', 'sure'),
#  ('Lots', 'sure'),
#  ('meat', 'sure'),
#  ('sauce', 'sure'),
#  ('pizza', 'amazing'),
#  ('waitress', 'sweet'),
#  ('menu', 'delish'),
#  ('names', 'delish'),
#  ('pastas', 'delish'),
#  ('deserts', 'delish'),
#  ('dish', 'amazing'),
#  ('canoli', 'amazing'),
#  ('cream', 'amazing'),
#  ('pieces', 'amazing'),
#  ('shell', 'amazing'),
#  ('zeppolis', 'ok'),
#  ('NY', 'small'),
#  ('home', 'small'),
#  ('reviews', 'worried'),
#  ('reviews', 'worried'),
#  ('oil', 'fine'),
#  ('change', 'fine'),
#  ('premium', 'fine'),
#  ('car', 'fine'),
#  ('wash', 'fine'),
#  ('oil', 'fine'),
#  ('change', 'fine'),
#  ('car', 'fine'),
#  ('wash', 'fine'),
#  ('antenna', 'good'),
#  ('hand', 'good'),
#  ('prints', 'good'),
#  ('doors', 'good'),
#  ('cashier', 'nice'),
#  ('Update', 'free'),
#  ('oil', 'free'),
#  ('morning', 'free'),
#  ('Delicious', 'nice'),
#  ('staff', 'nice'),
#  ('sauce', 'enough'),
#  ('food', 'enough'),
#  ('beef', 'good'),
#  ('brisket', 'good'),
#  ('meat', 'good'),
#  ('bread', 'good'),
#  ('reason', 'bad'),
#  ('place', 'bad'),
#  ('Tom', 'more'),
#  ('BBQ', 'more'),
#  ('sauce', 'more'),
#  ('Plan', 'more'),
#  ('location', 'nice'),
#  ('one', 'nice'),
#  ('Bethany', 'nice'),
#  ('Home', 'nice'),
#  ('Staff', 'nice'),
#  ('plenty', 'careful'),
#  ('games', 'careful'),
#  ('beer', 'brave'),
#  ('selection', 'brave'),
#  ('beer', 'disgusting'),
#  ('bat', 'nice'),
#  ('tender', 'nice'),
#  ('hotel', 'many'),
#  ('hotels', 'free'),
#  ('Las', 'free'),
#  ('Vegas', 'free'),
#  ('TON', 'free'),
#  ('perks', 'free'),
#  ('water', 'front'),
#  ('desk', 'free'),
#  ('wifi', 'free'),
#  ('breakfast', 'free'),
#  ('coffee', 'free'),
#  ('lobby', 'free'),
#  ('tasty', 'free'),
#  ('cookies', 'common'),
#  ('check', 'common'),
#  ('gym', 'common'),
#  ('hotels', 'Nice'),
#  ('rooms', 'Nice'),
#  ('decor', 'equipped'),
#  ('refrigerator', 'common'),
#  ('microwave', 'common'),
#  ('complaints', 'snug'),
#  ('toilet', 'dirty'),
#  ('area', 'dirty'),
#  ('door', 'dirty'),
#  ('bumps', 'dirty'),
#  ('toilet', 'dirty'),
#  ('light', 'dirty'),
#  ('shower', 'dirty'),
#  ('linoleum', 'dirty'),
#  ('floor', 'dirty'),
#  ('comforter', 'old'),
#  ('side', 'old'),
#  ('Location', 'great'),
#  ('airport', 'most'),
#  ('noise', 'most'),
#  ('midnight', 'most'),
#  ('am', 'most'),
#  ('mins', 'most'),
#  ('casinos', 'sure'),
#  ('Strip', 'sure'),
#  ('plenty', 'heavy'),
#  ('time', 'heavy'),
#  ('traffic', 'worse'),
#  ('Vegas', 'worse'),
#  ('Price', 'great'),
#  ('CES', 'less'),
#  ('night', 'nice'),
#  ('staff', 'nice'),
#  ('Great', 'big'),
#  ('Burgers', 'big'),
#  ('Fries', 'big'),
#  ('Happy', 'big'),
#  ('Tummy', 'big'),
#  ('Burger', 'prefab'),
#  ('feeling', 'prefab'),
#  ('Sandy', 'best'),
#  ('Mittens', 'best'),
#  ('hairdresser', 'perfect'),
#  ('years', 'perfect'),
#  ('hair', 'amazing'),
#  ('face', 'amazing'),
#  ('hair', 'amazing'),
#  ('color', 'nice'),
#  ('top', 'nice'),
#  ('Delicious', 'bright'),
#  ('tofu', 'bright'),
#  ('tacos', 'bright'),
#  ('lots', 'bright'),
#  ('veggies', 'excessive'),
#  ('reviews', 'disappointed'),
#  ('eyebrow', 'knowledgeable'),
#  ('threading', 'knowledgeable'),
#  ('spot', 'knowledgeable'),
#  ('stylist', 'knowledgeable'),
#  ('care', 'stray'),
#  ('hair', 'sure'),
#  ('time', 'perfect'),
#  ('brows', 'perfect'),
#  ('Juicy', 'Caramalized'),
#  ('Meaty', 'Caramalized'),
#  ('hangover', 'Caramalized'),
#  ('weeks', 'mini'),
#  ('vacation', 'great'),
#  ('friends', 'great'),
#  ('Vegas', 'great'),
#  ('Virgin', 'great'),
#  ('point', 'great'),
#  ('idea', 'great'),
#  ('location', 'great'),
#  ('strip', 'great'),
#  ('place', 'great'),
#  ('weather', 'nice'),
#  ('days', 'crowded'),
#  ('spot', 'easy'),
#  ('pool', 'easy'),
#  ('sun', 'easy'),
#  ('sun', 'warm'),
#  ('pools', 'warm'),
#  ('sand', 'warm'),
#  ('bottoms', 'warm'),
#  ('kiddie', 'warm'),
#  ('end', 'warm'),
#  ('pools', 'warm'),
#  ('bummer', 'hot'),
#  ('pool', 'waterful'),
#  ('kid', 'clear'),
#  ('hangout', 'clear'),
#  ('tub', 'sweet'),
#  ('rooms', 'nice'),
#  ('beds', 'comfy'),
#  ('suite', 'full'),
#  ('kitchen', 'large'),
#  ('living', 'large'),
#  ('room', 'large'),
#  ('area', 'large'),
#  ('couch', 'large'),
#  ('bathrooms', 'perfect'),
#  ('bedrooms', 'perfect'),
#  ('location', 'ok'),
#  ('food', 'wise'),
#  ('Tahiti', 'able'),
#  ('strip', 'able'),
#  ('mall', 'able'),
#  ('denny', 'liqour'),
#  ('breakfast', 'liqour'),
#  ('Qdoba', 'liqour'),
#  ('lunch', 'liqour'),
#  ('walgreens', 'liqour'),
#  ('snacks', 'liqour'),
#  ('stores', 'friendly'),
#  ('staff', 'friendly'),
#  ('package', 'happy'),
#  ('shuttle', 'happy'),
#  ('strip', 'happy'),
#  ('11:00pm', 'happy'),
#  ('Cabs', 'happy'),
#  ('strip', 'happy'),
#  ('purpose', 'happy'),
#  ('OPH', 'hard'),
#  ('parking', 'hard'),
#  ('lot', 'hard'),
#  ('weekends', 'least'),
#  ('morning', 'least'),
#  ('afternoon', 'least'),
#  ('week', 'least'),
#  ('frustration', 'worth'),
#  ('parking', 'worth'),
#  ('spot', 'worth'),
#  ('word', 'worth'),
#  ('guidance', 'worth'),
#  ('Original', 'worth'),
#  ('Pancake', 'worth'),
#  ('House', 'worth'),
#  ('effort', 'unplanned'),
#  ('Kay', 'unplanned'),
#  ('day', 'last'),
#  ('week', 'best'),
#  ('chance', 'full'),
#  ('lot', 'full'),
#  ('road', 'silver'),
#  ('castle', 'silver'),
#  ('sky', 'silver'),
#  ('gent', 'cinereal'),
#  ('luxury', 'urbane'),
#  ('car', 'urbane'),
#  ('glee', 'urbane'),
#  ('space', 'urbane'),
#  ('restaurant', 'urbane'),
#  ('wait', 'urbane'),
#  ('Kay', 'urbane'),
#  ('greying', 'urbane'),
#  ('fellow', 'elated'),
#  ('Brunchman', 'elated'),
#  ('table', 'young'),
#  ('Kay', 'young'),
#  ('pursuit', 'young'),
#  ('server', 'aspiring'),
#  ('name', 'aspiring'),
#  ('Nicole', 'aspiring'),
#  ('model', 'general'),
#  ('Kay', 'general'),
#  ('area', 'new'),
#  ('Nicole', 'new'),
#  ('friend', 'expansive'),
#  ('concerts', 'expansive'),
#  ('food', 'expansive'),
#  ('life', 'expansive'),
#  ('delecacies', 'expansive'),
#  ('OPH', 'expansive'),
#  ('bill', 'fresh'),
#  ('fare', 'fresh'),
#  ('strawberries', 'fresh'),
#  ('cream', 'first'),
#  ('course', 'ripe'),
#  ('obsession', 'ripe'),
#  ('dairy', 'ripe'),
#  ('product', 'ripe'),
#  ('strawberries', 'ripe'),
#  ('bowl', 'simple'),
#  ('alabaster', 'simple'),
#  ('cloud', 'simple'),
#  ('felicity', 'simple'),
#  ('cloud', 'simple'),
#  ('strawberries', 'simple'),
#  ('pleasures', 'lone'),
#  ('palate', 'lone'),
#  ('Crabcake', 'lone'),
#  ('Eggs', 'lone'),
#  ('Benedict', 'lone'),
#  ('complaint', 'tricky'),
#  ('Hollandaise', 'tricky'),
#  ('Sauce', 'tricky'),
#  ('thing', 'genuine'),
#  ('results', 'genuine'),
#  ('case', 'genuine'),
#  ('egg', 'genuine'),
#  ('yolks', 'genuine'),
#  ('eggs', 'genuine'),
#  ('duo', 'genuine'),
#  ('crabcakes', 'genuine'),
#  ('meat', 'English'),
#  ('buttery', 'English'),
#  ('muffins', 'plush'),
#  ('remoulade', 'bland'),
#  ('dish', 'bland'),
#  ('saving', 'bland'),
#  ('grace', 'bland'),
#  ('wedding', 'bland'),
#  ('tangy', 'bland'),
#  ('Hollandaise', 'crispy'),
#  ('sauce', 'crispy'),
#  ('Psst', 'crispy'),
#  ('Brunchman', 'crispy'),
#  ('mom', 'crispy'),
#  ('Hollandaise', 'crispy'),
#  ('recipe', 'crispy'),
#  ('Kay', 'crispy'),
#  ('Coconut', 'crispy'),
#  ('Pancakes', 'crispy'),
#  ('butter', 'esoteric'),
#  ('syrup', 'sheer'),
#  ('Paradise', 'sugariness'),
#  ('fruity', 'sugariness'),
#  ('Kay', 'large'),
#  ('order', 'large'),
#  ('Corned', 'large'),
#  ('Beef', 'large'),
#  ('Hash', 'large'),
#  ('potatoes', 'flawless'),
#  ('beef', 'kosher'),
#  ('Kay', 'happy'),
#  ('pancakes', 'happy'),
#  ('Dutch', 'ablaze'),
#  ('Baby', 'ablaze'),
#  ('mother', 'ablaze'),
#  ('whispers', 'ablaze'),
#  ('experience', 'ablaze'),
#  ('North', 'ablaze'),
#  ('Hills', 'ablaze'),
#  ('OPH', 'ablaze'),
#  ('minutes', 'ablaze'),
#  ('order', 'ablaze'),
#  ('rest', 'ablaze'),
#  ('brunch', 'ablaze'),
#  ('Minutes', 'ablaze'),
#  ('front', 'ablaze'),
#  ('Brunchman', 'ablaze'),
#  ('consultation', 'ablaze'),
#  ('eyes', 'ablaze'),
#  ('arms', 'about'),
#  ('oscillating', 'about'),
#  ('spell', 'powdered'),
#  ('butter', 'powdered'),
#  ('interior', 'powdered'),
#  ('errr', 'powdered'),
#  ('baby', 'powdered'),
#  ('lemon', 'powdered'),
#  ('sugar', 'ready'),
#  ('lecture', 'ready'),
#  ('fingers', 'ready'),
#  ('beam', 'ready'),
#  ('lips', 'ready'),
#  ('tomorrow', 'ready'),
#  ('morning', 'ready'),
#  ('service', 'doughy'),
#  ('Brunchman', 'doughy'),
#  ('instructions', 'doughy'),
#  ('Dutch', 'doughy'),
#  ('Baby', 'doughy'),
#  ('pancake', 'doughy'),
#  ('bowl', 'doughy'),
#  ('love', 'lardy'),
#  ('butter', 'sweet'),
#  ('sugar', 'acidic'),
#  ('lemon', 'amiss'),
#  ('Syrup', 'young'),
#  ('puff', 'young'),
#  ('Nicole', 'young'),
#  ('Brunchman', 'young'),
#  ('finger', 'young'),
#  ...]

# %% [markdown]
# #### Find the top 10 most frequent noun-adjective pairs

# %%
counter=collections.Counter(noun_adj_pairs)
print(counter.most_common(10))
# Out:
# [(('food', 'good'), 4), (('staff', 'friendly'), 3), (('place', 'great'), 3), (('pho', 'regular'), 3), (('issue', 'same'), 2), (('sashimi', 'large'), 2), (('eel', 'nice'), 2), (('course', 'nice'), 2), (('Sushi', 'full'), 2), (('time', 'happy'), 2)]

# %% [markdown]
# ## 5 star ratings
# #### Randomly select 50 reviews from different businesses with rating 5

# %%
# Filter reviews with 5 star and store in a dataframe
fiveStar = data[data['stars']==5]

# Group by business ID and sample a random 5-star review from each group (1 per business)
grouped = oneStar.groupby('business_id').sample(n=1)

# Randomly select 50 reviews of rating 5 (one from each business)
random50 = grouped.sample(n=50)

# %% [markdown]
# #### Extract all noun-adjective pairs

# %%
nlp = spacy.load('en_core_web_sm')
noun_adj_pairs = []

for i in random50['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((str(token),str(doc[j])))
              break
noun_adj_pairs
# Out:
# [('11PM', 'stuck'),
#  ('Mississauga', 'stuck'),
#  ('Sunday', 'stuck'),
#  ('night', 'stuck'),
#  ('Pizza', 'terrible'),
#  ('Nova', 'terrible'),
#  ('Pizza', 'terrible'),
#  ('Pizza', 'terrible'),
#  ('thing', 'few'),
#  ('Burger', 'few'),
#  ('Factory', 'few'),
#  ('place', 'few'),
#  ('group', 'few'),
#  ('people', 'few'),
#  ('employee', 'few'),
#  ('minutes', 'alone'),
#  ('burgers', 'mad'),
#  ('cheeseburger', 'basic'),
#  ('onions', 'basic'),
#  ('ketchup', 'basic'),
#  ('tomato', 'basic'),
#  ('lettuce', 'basic'),
#  ('burger', 'delicious'),
#  ('piece', 'sad'),
#  ('meat', 'sad'),
#  ('patties', 'sad'),
#  ('second', 'next'),
#  ('day', 'expensive'),
#  ('place', 'expensive'),
#  ('burger', 'better'),
#  ('places', 'better'),
#  ('quality', 'different'),
#  ('burger', 'different'),
#  ('place', 'different'),
#  ('expectations', 'different'),
#  ('waiting', 'tricky'),
#  ('room', 'tricky'),
#  ('reading', 'tricky'),
#  ('material', 'tricky'),
#  ('bit', 'tricky'),
#  ('time', 'cool'),
#  ('experience', 'better'),
#  ('customer', 'better'),
#  ('service', 'better'),
#  ('way', 'happy'),
#  ('Barneys', 'best'),
#  ('stores', 'best'),
#  ('Las', 'best'),
#  ('Vegas', 'best'),
#  ('location', 'best'),
#  ('salesperson', 'particular'),
#  ('Chicagoan', 'personable'),
#  ('German', 'personable'),
#  ('Herman', 'personable'),
#  ('Men', 'personable'),
#  ('department', 'personable'),
#  ('clothing', 'personable'),
#  ('decision', 'personable'),
#  ('store', 'typical'),
#  ('design', 'typical'),
#  ('layout', 'typical'),
#  ('Barneys', 'eclectic'),
#  ('food', 'dirty'),
#  ('bit', 'dirty'),
#  ('times', 'first'),
#  ('time', 'disgusting'),
#  ('floor', 'same'),
#  ('thing', 'many'),
#  ('day', 'many'),
#  ('times', 'okay'),
#  ('service', 'okay'),
#  ('food', 'hot'),
#  ('mix', 'korean'),
#  ('food', 'helpful'),
#  ('menu', 'helpful'),
#  ('pictures', 'helpful'),
#  ('english', 'helpful'),
#  ('item', 'good'),
#  ('appetizers', 'hard'),
#  ('place', 'hard'),
#  ('bit', 'hard'),
#  ('plaza', 'main'),
#  ('Kinkade', 'favorite'),
#  ('place', 'friendly'),
#  ('car', 'friendly'),
#  ('oil', 'friendly'),
#  ('change', 'friendly'),
#  ('guys', 'friendly'),
#  ('Groupon', 'busy'),
#  ('deal', 'busy'),
#  ('place', 'busy'),
#  ('Keurig', 'busy'),
#  ('coffee', 'busy'),
#  ('station', 'busy'),
#  ('tv', 'busy'),
#  ('appointment', 'busy'),
#  ('place', 'busy'),
#  ('parking', 'small'),
#  ('lot', 'small'),
#  ('tonight', 'excellent'),
#  ('toppings', 'half'),
#  ('candy', 'great'),
#  ('bars', 'great'),
#  ('flavor', 'amazing'),
#  ('selection', 'amazing'),
#  ('flavor', 'only'),
#  ('favorite', 'only'),
#  ('things', 'expensive'),
#  ('bit', 'expensive'),
#  ('ounce', 'other'),
#  ('places', 'frequent'),
#  ('yogurt', 'more'),
#  ('shops', 'more'),
#  ('fat', 'free'),
#  ('idea', 'free'),
#  ('rewards', 'free'),
#  ('card', 'free'),
#  ('price', 'few'),
#  ('visits', 'few'),
#  ('BBQ', 'more'),
#  ('pork', 'more'),
#  ('banh', 'more'),
#  ('mi', 'more'),
#  ('pork', 'GREAT'),
#  ('sandwich', 'delicious'),
#  ('food', 'delicious'),
#  ('fridges', 'delicious'),
#  ('service', 'quick'),
#  ('prices', 'affordable'),
#  ('deals', 'nice'),
#  ('day', 'little'),
#  ('food', 'little'),
#  ('friends', 'old'),
#  ('year', 'old'),
#  ('daughters', 'Most'),
#  ('birthday', 'Most'),
#  ('milestone', 'Most'),
#  ('restaurant', 'Most'),
#  ('kids', 'Swiss'),
#  ('South', 'Swiss'),
#  ('Street', 'Swiss'),
#  ('Burger', 'Swiss'),
#  ('Guys', 'Swiss'),
#  ('Chalet', 'amazing'),
#  ('food', 'amazing'),
#  ('choice', 'impressed'),
#  ('Jack', 'impressed'),
#  ('Astor', 'impressed'),
#  ('past', 'impressed'),
#  ('Vaughan', 'impressed'),
#  ('while', 'open'),
#  ('mind', 'nice'),
#  ('Restaurant', 'nice'),
#  ('atmosphere', 'busy'),
#  ('Easter', 'memorable'),
#  ('Monday', 'memorable'),
#  ('server', 'memorable'),
#  ('Josh', 'memorable'),
#  ('table', 'memorable'),
#  ('drink', 'memorable'),
#  ('order', 'memorable'),
#  ('food', 'memorable'),
#  ('order', 'memorable'),
#  ('visit', 'memorable'),
#  ('menu', 'best'),
#  ('Pad', 'best'),
#  ('Thai', 'best'),
#  ('recommendation', 'excellent'),
#  ('bang', 'excellent'),
#  ('Kudos', 'small'),
#  ('menu', 'small'),
#  ('brownie', 'small'),
#  ('end', 'small'),
#  ('meal', 'small'),
#  ('year', 'small'),
#  ('olds', 'small'),
#  ('birthday', 'small'),
#  ('sparkler', 'small'),
#  ('girl', 'small'),
#  ('fun', 'small'),
#  ('birthday', 'small'),
#  ('day', 'small'),
#  ('gesture', 'excellent'),
#  ('comment', 'excellent'),
#  ('fans', 'excellent'),
#  ('adults', 'excellent'),
#  ('Pad', 'excellent'),
#  ('Thai', 'excellent'),
#  ('year', 'old'),
#  ('Deluxe', 'other'),
#  ('Burger', 'other'),
#  ('fries', 'other'),
#  ('dining', 'delicious'),
#  ('companions', 'delicious'),
#  ('Steak', 'delicious'),
#  ('Sandwich', 'delicious'),
#  ('steak', 'delicious'),
#  ('sandwich', 'embarrassing'),
#  ('plates', 'embarrassing'),
#  ('plates', 'excellent'),
#  ('food', 'excellent'),
#  ('atmosphere', 'good'),
#  ('service', 'spectacular'),
#  ('thanks', 'interesting'),
#  ('Josh', 'interesting'),
#  ('restaurant', 'negative'),
#  ('reviews', 'glad'),
#  ('walk', 'last'),
#  ('minute', 'bent'),
#  ('beauty', 'bent'),
#  ('fix', 'bent'),
#  ('hurry', 'bent'),
#  ('threading', 'bent'),
#  ('brows', 'bent'),
#  ('lady', 'bent'),
#  ('front', 'bent'),
#  ('shape', 'big'),
#  ('delay', 'big'),
#  ('appointment', 'big'),
#  ('lady', 'big'),
#  ('payment', 'big'),
#  ('phone', 'big'),
#  ('threading', 'big'),
#  ('deal', 'own'),
#  ('person', 'own'),
#  ('eyebrows', 'own'),
#  ('frustration', 'same'),
#  ('appointment', 'same'),
#  ('minutes', 'same'),
#  ('walk', 'same'),
#  ('ins', 'same'),
#  ('priority', 'potential'),
#  ('service', 'potential'),
#  ('end', 'potential'),
#  ('result', 'potential'),
#  ('today', 'delicious'),
#  ('lunch', 'delicious'),
#  ('special', 'delicious'),
#  ('MOLE', 'delicious'),
#  ('stuff', 'delicious'),
#  ('w/', 'delicious'),
#  ('side', 'perfect'),
#  ('beans', 'perfect'),
#  ('rice', 'perfect'),
#  ('size', 'warm'),
#  ('w/', 'warm'),
#  ('toritlla', 'last'),
#  ('place', 'last'),
#  ('years', 'pretty'),
#  ('descent', 'traditional'),
#  ('Meal', 'tasty'),
#  ('service', 'reasonable'),
#  ('Portions', 'reasonable'),
#  ('price', 'clean'),
#  ('restroom', 'clean'),
#  ('chain', 'good'),
#  ('breakfast', 'good'),
#  ('place', 'good'),
#  ('sit', 'fast'),
#  ('place', 'fast'),
#  ('food', 'same'),
#  ('kitchen', 'same'),
#  ('setup', 'same'),
#  ('machine', 'less'),
#  ('assembly', 'less'),
#  ('line', 'less'),
#  ('menu', 'less'),
#  ('bit', 'less'),
#  ('Denny', 'less'),
#  ('choices', 'more'),
#  ('prices', 'more'),
#  ('bit', 'more'),
#  ('place', 'worth'),
#  ('food', 'worth'),
#  ('amount', 'worth'),
#  ('waitresses', 'certain'),
#  ('tables', 'certain'),
#  ('order', 'certain'),
#  ('counter', 'certain'),
#  ('order', 'certain'),
#  ('way', 'other'),
#  ('lead', 'other'),
#  ('people', 'specific'),
#  ('job', 'basic'),
#  ('lead', 'basic'),
#  ('bread', 'basic'),
#  ('waffle', 'basic'),
#  ('irons', 'basic'),
#  ('others', 'basic'),
#  ('potatoes', 'basic'),
#  ('eggs', 'basic'),
#  ('meats', 'basic'),
#  ('meal', 'cooked'),
#  ('eggs', 'cooked'),
#  ('potatoes', 'cooked'),
#  ('bacon', 'cooked'),
#  ('sausage', 'cooked'),
#  ('toast', 'cooked'),
#  ('grits', 'cooked'),
#  ('potatoes', 'cooked'),
#  ('grits', 'cooked'),
#  ('bacon', 'cooked'),
#  ('wheat', 'fun'),
#  ('potatoes', 'fun'),
#  ('bacon', 'fun'),
#  ('sourdough', 'fun'),
#  ('production', 'fun'),
#  ('thing', 'few'),
#  ('food', 'few'),
#  ('orders', 'few'),
#  ('front', 'few'),
#  ('cooks', 'few'),
#  ('memory', 'few'),
#  ('people', 'different'),
#  ('rolls', 'funny'),
#  ('nuances', 'good'),
#  ('waffle', 'good'),
#  ('house', 'good'),
#  ('machine', 'good'),
#  ('food', 'good'),
#  ('bit', 'good'),
#  ('greasy', 'good'),
#  ('lots', 'good'),
#  ('food', 'good'),
#  ('sushi', 'good'),
#  ('checklist', 'good'),
#  ('stuff', 'good'),
#  ('pizza', 'double'),
#  ('menu', 'double'),
#  ('price', 'double'),
#  ('items', 'double'),
#  ('fact', 'double'),
#  ('Charge', 'double'),
#  ('People', 'free'),
#  ('food', 'free'),
#  ('excuse', 'own'),
#  ('house', 'acceptable'),
#  ('time', 'acceptable'),
#  ('guys', 'great'),
#  ('gals', 'great'),
#  ('Classic', 'great'),
#  ('Car', 'great'),
#  ('Spa', 'great'),
#  ('performance', 'Happy'),
#  ('Tesla', 'Happy'),
#  ('TLC', 'Happy'),
#  ('wife', 'Happy'),
#  ('ride', 'Happy'),
#  ('wife', 'Happy'),
#  ('burger', 'fun'),
#  ('milkshake', 'fun'),
#  ('jukebox', 'fun'),
#  ('lunch', 'favorite'),
#  ('spot', 'favorite'),
#  ('thing', 'spicy'),
#  ('gyro', 'spicy'),
#  ('pita', 'spicy'),
#  ('gyro', 'many'),
#  ('places', 'great'),
#  ('one', 'great'),
#  ('fare', 'ok'),
#  ('restaurant', 'accurate'),
#  ('chicken', 'accurate'),
#  ('hours', 'accurate'),
#  ('Yelp', 'accurate'),
#  ('pm', 'pleasant'),
#  ('place', 'pleasant'),
#  ('surprise', 'other'),
#  ('restaurants', 'clean'),
#  ('place', 'clean'),
#  ('Owl', 'sticky'),
#  ('Minerva', 'sticky'),
#  ('floors', 'unpleasant'),
#  ('odour', 'stinky'),
#  ('Kayagum', 'stinky'),
#  ('seats', 'stinky'),
#  ('tables', 'better'),
#  ('place', 'better'),
#  ('banchan', 'huge'),
#  ('kalbi', 'huge'),
#  ('erving', 'juicy'),
#  ('Tender', 'juicy'),
#  ('meat', 'purple'),
#  ('rice', 'favorite'),
#  ('bf', 'favorite'),
#  ('meat', 'favorite'),
#  ('heaven', 'favorite'),
#  ('gamjatang', 'much'),
#  ('others', 'spicier'),
#  ('Meat', 'spicier'),
#  ('bone', 'spicier'),
#  ('tender', 'spicier'),
#  ('version', 'curious'),
#  ('dishes', 'good'),
#  ('thing', 'open'),
#  ('hours', 'Korean'),
#  ('Novanta', 'authentic'),
#  ('Napoletan', 'worth'),
#  ('Pizza', 'worth'),
#  ('case', 'worth'),
#  ('way', 'fresh'),
#  ('shot', 'fresh'),
#  ('positives', 'fresh'),
#  ('negatives', 'fresh'),
#  ('house', 'fresh'),
#  ('salad', 'fresh'),
#  ('tray', 'fresh'),
#  ('pizza', 'fresh'),
#  ('Balsamic', 'fresh'),
#  ('Vinaigrette', 'fresh'),
#  ('vegetables', 'fresh'),
#  ('salad', 'easy'),
#  ('salads', 'specific'),
#  ('restaurant', 'specific'),
#  ('lifetime', 'specific'),
#  ('pizza', 'specific'),
#  ('wife', 'specific'),
#  ('times', 'amazing'),
#  ('son', 'amazing'),
#  ('pizza', 'amazing'),
#  ('lot', 'visible'),
#  ('sauce', 'visible'),
#  ('atmosphere', 'excellent'),
#  ('service', 'superb'),
#  ('negatives', 'minor'),
#  ('one', 'comfortable'),
#  ('chairs', 'comfortable'),
#  ('comfort', 'minor'),
#  ('couch', 'minor'),
#  ('side', 'minor'),
#  ('negative', 'more'),
#  ('Gelato', 'more'),
#  ('Gelato', 'more'),
#  ('Vanilla', 'more'),
#  ('Bean', 'more'),
#  ('ice', 'more'),
#  ('cream', 'more'),
#  ('vanilla', 'more'),
#  ('flavor', 'more'),
#  ('order', 'more'),
#  ('ice', 'positive'),
#  ('cream', 'positive'),
#  ('Gelato', 'positive'),
#  ('Gelato', 'positive'),
#  ('Alino', 'positive'),
#  ('Mooresville', 'positive'),
#  ('side', 'positive'),
#  ('note', 'positive'),
#  ('pizza', 'good'),
#  ('salad', 'good'),
#  ('person', 'good'),
#  ('clip', 'good'),
#  ('deal', 'traditional'),
#  ('individual', 'traditional'),
#  ('family', 'traditional'),
#  ('group', 'traditional'),
#  ('pizza', 'several'),
#  ('shop', 'several'),
#  ('pie', 'several'),
#  ('people', 'unique'),
#  ('premium', 'unique'),
#  ('Original', 'delicious'),
#  ('Pancake', 'delicious'),
#  ('House', 'delicious'),
#  ('breakfast', 'delicious'),
#  ('favorite', 'fresh'),
#  ('strawberry', 'fresh'),
#  ('pancakes', 'fresh'),
#  ('strawberries', 'good'),
#  ('cream', 'good'),
#  ('house', 'good'),
#  ('strawberry', 'good'),
#  ('syrup', 'good'),
#  ('omelettes', 'good'),
#  ('portions', 'huge'),
#  ('prices', 'good'),
#  ('meat', 'marinated'),
#  ('Toronto', 'marinated'),
#  ('place', 'marinated'),
#  ('steaks', 'marinated'),
#  ('chicken', 'marinated'),
#  ('lamb', 'marinated'),
#  ('pork', 'marinated'),
#  ('sauces', 'delicious'),
#  ('dish', 'delicious'),
#  ('taste', 'amazing'),
#  ('sauce', 'perfect'),
#  ('steaks', 'few'),
#  ('cons', 'special'),
#  ('sea', 'special'),
#  ('food', 'special'),
#  ('dishes', 'special'),
#  ('taste', 'OK'),
#  ('sauce', 'worth'),
#  ('meat', 'worth'),
#  ('salads', 'worth'),
#  ('price', 'tasty'),
#  ('Hakkasan', 'normal'),
#  ('casino', 'Expensive'),
#  ('bar', 'Expensive'),
#  ('drinks', 'unexpected'),
#  ('spot', 'friendly'),
#  ('people', 'friendly'),
#  ('scene', 'friendly'),
#  ('bartenders', 'friendly'),
#  ('wife', 'favorite'),
#  ('Tapas', 'favorite'),
#  ('places', 'good'),
#  ('Tapas', 'good'),
#  ('Vegas', 'good'),
#  ('couple', 'good'),
#  ('times', 'good'),
#  ('food', 'good'),
#  ('service', 'good'),
#  ('place', 'larger'),
#  ('group', 'sure'),
#  ('fun', 'sure'),
#  ('selection', 'sure'),
#  ('Tapas', 'sure'),
#  ('room', 'tasty'),
#  ('Paella', 'tasty'),
#  ('variety', 'worth'),
#  ('Sangria', 'worth'),
#  ('Vegas', 'great'),
#  ('place', 'great'),
#  ('Mall', 'great'),
#  ('view', 'fun'),
#  ('Strip', 'fun'),
#  ('Wynn', 'fun'),
#  ('beer', 'good'),
#  ('selection', 'good'),
#  ('draft', 'good'),
#  ('bottle', 'good'),
#  ('Food', 'good'),
#  ('Patio', 'best'),
#  ('Barro', 'little'),
#  ('pizza', 'little'),
#  ('sitting', 'little'),
#  ('downsides', 'little'),
#  ('perks', 'little'),
#  ('day', 'little'),
#  ('coworkers', 'little'),
#  ('box', 'few'),
#  ('lunch', 'few'),
#  ('specials', 'few'),
#  ('slice', 'few'),
#  ('lunch', 'few'),
#  ('days', 'small'),
#  ('pizza', 'small'),
#  ('slice', 'small'),
#  ('pizza', 'long'),
#  ('coworkers', 'long'),
#  ('wait', 'long'),
#  ('minutes', 'same'),
#  ('lunch', 'hot'),
#  ('melty', 'delicious'),
#  ('gooey', 'delicious'),
#  ('delicious', 'delicious'),
#  ('slice', 'delicious'),
#  ('days', 'delicious'),
#  ('form', 'delicious'),
#  ('Barro', 'delicious'),
#  ('pizza', 'delicious'),
#  ('Karaikudi', 'special'),
#  ('place', 'weekly'),
#  ('roster', 'Fried'),
#  ('thanks', 'Fried'),
#  ('Fish', 'pleasant'),
#  ('King', 'pleasant'),
#  ('fish', 'pleasant'),
#  ('Wifey', 'pleasant'),
#  ('server', 'pleasant'),
#  ('guy', 'same'),
#  ('time', 'same'),
#  ('person', 'dumb'),
#  ('name', 'comfortable'),
#  ('places', 'comfortable'),
#  ('area', 'Standard'),
#  ('plenty', 'Standard'),
#  ('parking', 'Standard'),
#  ('weekends', 'Standard'),
#  ('wait', 'Standard'),
#  ('Food', 'Standard'),
#  ('items', 'good'),
#  ('Dosas', 'good'),
#  ('Vada', 'good'),
#  ('appetizers', 'good'),
#  ('Kothu', 'worth'),
#  ('Roti', 'worth'),
#  ('penny', 'best'),
#  ('Mutton', 'best'),
#  ('Biryaani', 'best'),
#  ('Dr.', 'excellent'),
#  ('Wellish', 'excellent'),
#  ('job', 'friendly'),
#  ('eyes', 'friendly'),
#  ('doctor', 'right'),
#  ('Dr.', 'right'),
#  ('Wellish', 'right'),
#  ('warning', 'right'),
#  ('LASIK', 'right'),
#  ('cusp', 'more'),
#  ('PRK', 'more'),
#  ('discomfort', 'little'),
#  ('LASIK', 'little'),
#  ('healing', 'little'),
#  ('time', 'little'),
#  ('story', 'more'),
#  ('difference', 'angry'),
#  ('vasectomy', 'angry'),
#  ('LASIK', 'angry'),
#  ('gorilla', 'only'),
#  ('tear', 'only'),
#  ('testicles', 'only'),
#  ('PRK', 'only'),
#  ('solution', 'implantable'),
#  ('PRK', 'implantable'),
#  ('contact', 'able'),
#  ('lenses', 'able'),
#  ('PRK', 'able'),
#  ('jack', 'implantable'),
#  ('shit', 'implantable'),
#  ('MONTHS', 'implantable'),
#  ('LASIK', 'implantable'),
#  ('contact', 'Other'),
#  ('lenses', 'Other'),
#  ('PRK', 'Other'),
#  ('gel', 'regular'),
#  ('mani', 'regular'),
#  ('nail', 'horrid'),
#  ('salon', 'horrid'),
#  ('place', 'horrid'),
#  ('nail', 'horrid'),
#  ('girl', 'horrid'),
#  ('nails', 'horrid'),
#  ('gel', 'bad'),
#  ('eek', 'bad'),
#  ('MD', 'great'),
#  ('Nail', 'great'),
#  ('Spa', 'great'),
#  ('spot', 'quick'),
#  ('appointment', 'cute'),
#  ('care', 'cute'),
#  ('salon', 'sweet'),
#  ('staff', 'regular'),
#  ('loads', 'regular'),
#  ('gel', 'regular'),
#  ('color', 'regular'),
#  ('selections', 'regular'),
#  ('loads', 'regular'),
#  ('colors', 'nice'),
#  ('walls', 'nice'),
#  ('polish', 'nice'),
#  ('gel', 'nice'),
#  ('manicure', 'nice'),
#  ('cuticle', 'dry'),
#  ('trimming', 'dry'),
#  ('areas', 'next'),
#  ('cuticle', 'next'),
#  ('level', 'standard'),
#  ('pedicure', 'standard'),
#  ('pedicure', 'hot'),
#  ('pedi', 'hot'),
#  ('stone', 'hot'),
#  ('towel', 'worth'),
#  ('massage', 'worth'),
#  ('Gee', 'worth'),
#  ('Vinny', 'best'),
#  ('pedi', 'best'),
#  ('pedi', 'Great'),
#  ('massage', 'Great'),
#  ('pressure', 'long'),
#  ('minute', 'nicest'),
#  ('massage', 'nicest'),
#  ('feature', 'late'),
#  ('MD', 'late'),
#  ('Nail', 'late'),
#  ('Spa', 'late'),
#  ('hours', 'open'),
#  ('star', 'exceptional'),
#  ('ratings', 'exceptional'),
#  ('experiences', 'good'),
#  ('stars', 'good'),
#  ('fan', 'good'),
#  ('regular', 'good'),
#  ('times', 'good'),
#  ('visit', 'good'),
#  ('service', 'good'),
#  ('food', 'good'),
#  ('atmosphere', 'good'),
#  ('area', 'good'),
#  ('Sloppy', 'good'),
#  ('Joseph', 'good'),
#  ('fries', 'good'),
#  ('appetizer', 'good'),
#  ('bacon', 'good'),
#  ('meatloaf', 'good'),
#  ('group', 'great'),
#  ('people', 'great'),
#  ('group', 'great'),
#  ('people', 'great'),
#  ('place', 'phenomenal'),
#  ('customer', 'phenomenal'),
#  ('service', 'phenomenal'),
#  ('Groupon', 'busy'),
#  ('December', 'busy'),
#  ('things', 'busy'),
#  ('owners', 'entire'),
#  ('James', 'entire'),
#  ('purchase', 'entire'),
#  ('price', 'entire'),
#  ('Groupon', 'entire'),
#  ('chance', 'entire'),
#  ('Groupon', 'reasonable'),
#  ('value', 'reasonable'),
#  ('amount', 'great'),
#  ('time', 'great'),
#  ('expiry', 'great'),
#  ('fun', 'great'),
#  ('Impressive', 'great'),
#  ('Catch', 'great'),
#  ('show', 'great'),
#  ('newcomers', 'great'),
#  ('suggestion', 'good'),
#  ('food', 'good'),
#  ('menu', 'good'),
#  ('variety', 'careful'),
#  ('pub', 'careful'),
#  ('fare', 'careful'),
#  ('nachos', 'careful'),
#  ('wings', 'careful'),
#  ('wraps', 'careful'),
#  ('sandwiches', 'careful'),
#  ('Mac', 'careful'),
#  ('cheese', 'careful'),
#  ('shepards', 'careful'),
#  ('pie', 'careful'),
#  ('bar', 'careful'),
#  ('show', 'careful'),
#  ('food', 'careful'),
#  ('theatre', 'careful'),
#  ('couple', 'most'),
#  ('tables', 'most'),
#  ('seats', 'typical'),
#  ('chairs', 'tasty'),
#  ('rows', 'tasty'),
#  ('food', 'tasty'),
#  ('portions', 'improv'),
#  ('show', 'improv'),
#  ('Catch', 'improv'),
#  ('show', 'hilarious'),
#  ('teams', 'hilarious'),
#  ('skits', 'hilarious'),
#  ('audience', 'hilarious'),
#  ('participation', 'hilarious'),
#  ('quality', 'hilarious'),
#  ('scenes', 'hilarious'),
#  ('winner', 'hilarious'),
#  ('case', 'hilarious'),
#  ('show', 'hilarious'),
#  ('end', 'hilarious'),
#  ('show', 'hilarious'),
#  ('recommendation', 'wide'),
#  ('calendar', 'wide'),
#  ('events', 'wide'),
#  ('place', 'wide'),
#  ('variety', 'different'),
#  ('shows', 'different'),
#  ('stages', 'expensive'),
#  ('night', 'expensive'),
#  ('week', 'expensive'),
#  ('Ticket', 'expensive'),
#  ('prices', 'expensive'),
#  ('none', 'expensive'),
#  ('place', 'easy'),
#  ('subway', 'half'),
#  ('line', 'half'),
#  ('Ossington', 'half'),
#  ('station', 'half'),
#  ('star', 'hard'),
#  ('seat', 'next'),
#  ('bar', 'next'),
#  ('show', 'next'),
#  ('people', 'next'),
#  ('show', 'much'),
#  ('seating', 'tight'),
#  ('place', 'tight'),
#  ('theatre', 'tight'),
#  ('seating', 'tight'),
#  ('seats', 'hard'),
#  ('food', 'hard'),
#  ('lap', 'cheap'),
#  ('conclusion', 'cheap'),
#  ('place', 'cheap'),
#  ('HILARIOUS', 'whole'),
#  ('way', 'whole'),
#  ('night', 'whole'),
#  ('shows', 'whole'),
#  ('vegan', 'consistent'),
#  ('place', 'consistent'),
#  ('downtown', 'consistent'),
#  ('Mesa', 'consistent'),
#  ('schedule', 'open'),
#  ('yesterday', 'open'),
#  ('afternoon', 'open'),
#  ('store', 'open'),
#  ('Yelp', 'open'),
#  ('app', 'open'),
#  ('pm', 'bad'),
#  ('Worth', 'bad'),
#  ('food', 'other'),
#  ('Blue', 'other'),
#  ('Vegan', 'other'),
#  ('Fried', 'other'),
#  ('Chicken', 'other'),
#  ('Volstead', 'other'),
#  ('blueberry', 'other'),
#  ('BBQ', 'other'),
#  ('sauce', 'other'),
#  ('cole', 'other'),
#  ('slaw', 'other'),
#  ('cheese', 'other'),
#  ('potato', 'other'),
#  ('bun', 'other'),
#  ('items', 'sure'),
#  ('menu', 'sure'),
#  ('Tortas', 'only'),
#  ('fare', 'safe'),
#  ('reason', 'safe'),
#  ('ham', 'airy'),
#  ('cheese', 'airy'),
#  ('torta', 'airy'),
#  ('part', 'airy'),
#  ('sub', 'airy'),
#  ('panini', 'airy'),
#  ('bread', 'airy'),
#  ('amountof', 'individual'),
#  ('sweetnes', 'individual'),
#  ('ham', 'individual'),
#  ('nosh', 'individual'),
#  ('bread', 'individual'),
#  ('bread', 'individual'),
#  ('sale', 'yummy'),
#  ('Boo', 'yummy'),
#  ('fruit', 'yummy'),
#  ('drinks', 'yummy'),
#  ('dining', 'loud'),
#  ('area', 'loud'),
#  ('side', 'loud'),
#  ('bakery', 'loud'),
#  ('TV', 'loud'),
#  ('ventilation', 'limited'),
#  ('parking', 'limited'),
#  ('tire', 'worth'),
#  ('shop', 'worth'),
#  ('visit', 'da'),
#  ('hood', 'good'),
#  ('place', 'better'),
#  ('restaurants', 'better'),
#  ('markets', 'better'),
#  ('food', 'better'),
#  ('downside', 'more'),
#  ('store', 'whole'),
#  ('food', 'whole'),
#  ('meat', 'whole'),
#  ('section', 'whole'),
#  ('faint', 'whole'),
#  ('heart', 'whole'),
#  ('lamb', 'good'),
#  ('heads', 'good'),
#  ('babaganoush', 'good'),
#  ('flavor', 'little'),
#  ('texture', 'little'),
#  ('bits', 'garlic'),
#  ('eggplant', 'garlic'),
#  ('chicken', 'garlic'),
#  ('shwarma', 'garlic'),
#  ('sauce', 'great'),
#  ('pickles', 'great'),
#  ('meat', 'great'),
#  ('cheese', 'great'),
#  ('spinach', 'great'),
#  ('pies', 'great'),
#  ('appetizer', 'honest'),
#  ('place', 'best'),
#  ('music', 'best'),
#  ('friends', 'best'),
#  ('place', 'little'),
#  ('space', 'small'),
#  ('front', 'small'),
#  ('stage', 'small'),
#  ('friends', 'many'),
#  ('wife', 'many'),
#  ('front', 'many'),
#  ('eyes', 'many'),
#  ('pm', 'many'),
#  ('shots', 'whole'),
#  ('crowd', 'fun'),
#  ('mind', 'mid'),
#  ('twenties', 'early'),
#  ('bit', 'early'),
#  ('place', 'early'),
#  ('thirties', 'late'),
#  ('twenties', 'good'),
#  ('forties', 'good'),
#  ('drinks', 'good'),
#  ('Jaeger', 'great'),
#  ('Bombs', 'great'),
#  ('tequila', 'great'),
#  ('shots', 'great'),
#  ('slices', 'generous'),
#  ('toppings', 'typical'),
#  ('New', 'thin'),
#  ('York', 'thin'),
#  ('style', 'thin'),
#  ('pizza', 'thin'),
#  ('mood', 'thin'),
#  ('crust-', 'open'),
#  ('spot', 'open'),
#  ('pedicures', 'sanitary'),
#  ('liners', 'disposable'),
#  ('pumice', 'disposable'),
#  ('emery', 'disposable'),
#  ('boards', 'disposable'),
#  ('pedicure', 'best'),
#  ('chairs', 'best'),
#  ('massage', 'upper'),
#  ('chairs', 'upper'),
#  ('specials', 'regular'),
#  ('burgers', 'little'),
#  ('specials', 'EXCELLENT'),
#  ('deal', 'single'),
#  ('life', 'single'),
#  ('goal', 'single'),
#  ('one', 'least'),
#  ('favorites', 'little'),
#  ('Burgerrito', 'little'),
#  ('Burger', 'little'),
#  ('times', 'little'),
#  ('hours', 'worth'),
#  ('rush', 'worth'),
#  ('dinner', 'empty'),
#  ('place', 'empty'),
#  ('setup', 'Most'),
#  ('Subway', 'Most'),
#  ('Chipotle', 'Most'),
#  ('signature', 'Most'),
#  ('bowl', 'Most'),
#  ('ingredients', 'Most'),
#  ('days', 'rare'),
#  ('vegan', 'rare'),
#  ('cheat', 'overwhelmed'),
#  ('day', 'overwhelmed'),
#  ('options', 'simple'),
#  ('signature', 'simple'),
#  ('bowls', 'simple'),
#  ('Volcano', 'simple'),
#  ('wife', 'simple'),
#  ('Point', 'simple'),
#  ('bowl', 'simple'),
#  ('daughter', 'simple'),
#  ('bowl', 'first'),
#  ('rice', 'first'),
#  ('shrimp', 'first'),
#  ('time', 'expensive'),
#  ('poke', 'expensive'),
#  ('place', 'clean'),
#  ('service', 'friendly'),
#  ('staff', 'friendly'),
#  ('reason', 'better'),
#  ('Star', 'better'),
#  ('ambiance', 'better'),
#  ('poke', 'high'),
#  ('places', 'high'),
#  ('Gilbert', 'high'),
#  ('area', 'high'),
#  ('place', 'high'),
#  ('bar', 'high'),
#  ('milk', 'great'),
#  ('tea', 'great'),
#  ('boba', 'great'),
#  ('choice', 'great'),
#  ('Arizona', 'great'),
#  ('options', 'other'),
#  ('smoothies', 'other'),
#  ('treats', 'picky'),
#  ('boba', 'right'),
#  ('texture', 'right'),
#  ('amount', 'nice'),
#  ('chew', 'nice'),
#  ('Service', 'nice'),
#  ('options', 'local'),
#  ('coffee', 'local'),
#  ('options', 'local'),
#  ('cookies', 'local'),
#  ('value', 'good'),
#  ('food', 'good'),
#  ('Ordered', 'good'),
#  ('Nem', 'good'),
#  ('Nuong', 'good'),
#  ...]

# %% [markdown]
# #### Find the top 10 most frequent noun-adjective pairs

# %%
counter=collections.Counter(noun_adj_pairs)
print(counter.most_common(10))
# Out:
# [(('food', 'good'), 7), (('Pizza', 'terrible'), 3), (('place', 'good'), 3), (('show', 'hilarious'), 3), (('thing', 'few'), 2), (('Groupon', 'busy'), 2), (('place', 'busy'), 2), (('food', 'delicious'), 2), (('service', 'quick'), 2), (('day', 'little'), 2)]
