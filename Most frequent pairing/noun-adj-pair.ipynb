# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import spacy
import collections

from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
data = pd.read_json('reviewSelected100.json',lines=True, 
                    orient='records',encoding = "ISO-8859-1")

# %%
display(data)
# Out:
#                     review_id                 user_id             business_id  \
# 0      8aoJJdKEO3ypoZNszpPu7Q  bGgAL09pxLnV_FFgR4ZADg  ZBE-H_aUlicix_9vUGQPIQ
# 1      J5NOCLdhuhor7USRhtYZ8w  pFCb-1j6oI3TDjr26h2cJQ  e-YnECeZNt8ngm0tu4X9mQ
# 2      PXiLWAYRt3xnHaJ8MB4rzw  mEzc6LeTNiQgIVsq3poMbg  j7HO1YeMQGYo3KibMXZ5vg
# 3      VrLarvxZYJm74yAqtpe9PQ  o-zUN2WEZgjQS7jnNsec0g  7e3PZzUpG5FYOTGt3O3ePA
# 4      C1CUpidlVFprUCkApqzCmA  Wlx0iBXJvk4x0EeOt2Bz1Q  vuHzLZ7nAeT-EiecOkS5Og
# ...                       ...                     ...                     ...
# 15295  qknwFVEh_0KSuexigYBI_A  YMGmyPOU65SMs4H60ltYiw  shIPnFoXrL3dFo5HLH1_HA
# 15296  Y-ZRoyAXCukBK1uK1ZcZCA  JLhOWQiWtGbr14K_KmoWxA  zPEYgVqJ2QNKi45FJi2jvg
# 15297  A8HdjBfhj3pgQuSbwNtDEw  6CoiKFDFXIACJZvv_I_8mQ  zPEYgVqJ2QNKi45FJi2jvg
# 15298  2n1QdrYBRAAe6GKaxEV0jA  _fH4s3ls08eSl_PfX38KIA  etzDsNjkCyQBoJcU2a3U-g
# 15299  4B9k5hmmLWV_lhIYvVcPWA  msRUiBE7Sa5A9145ZdFBow  9Xm2GfG8Rnbb1_CmXyrm3g
#
# ...

# %% [markdown]
# ## 1 star ratings
# #### Randomly select 50 reviews from different businesses with rating 1

# %%
# Filter reviews with 1 star and store in a dataframe
oneStar = data[data['stars']==1]

# %%
# Group by business ID and sample a random 1-star review from each group (1 per business)
grouped = oneStar.groupby('business_id').sample(n=1)
len(grouped)
# Out:
# 150

# %%
# Randomly select 50 reviews of rating 1 (one from each business)
random50 = grouped.sample(n=50)
#len(random50)
display(random50)
# Out:
#                     review_id                 user_id             business_id  \
# 12469  3zIIHMC4rn1wCDynJJASrw  NWrecl5hjADiE3eRt-8jjA  uhyDNWYRSsom3VrFgOgP_w
# 12211  rUVelAnt2ik9zo3bhwjUJg  yUQ8AppK7_UFWVN_GTgj6Q  Jcyu0ml7rxizEA8giSH-8A
# 7964   14vx82CnZ3lv4t-wkAgZ-g  nTC2GYTpgItpJ-G3nJTDDg  8Z72HW5ydzQFydUxZglurg
# 194    irVY4u1_VVuM947W3L-EWw  F92LE5jEaKMaNcjfCJjYZg  e-YnECeZNt8ngm0tu4X9mQ
# 240    zhWT0qoJOXgTl31b3nsfrg  2zTfjuF38dRi2qXsF1HpIg  k99YNCx5KcQPR7oeTgAOzg
# 13127  PPil8vilnt2bHzYr0j5uTQ  127yVH9erNmQYN7LE-fk4g  RyaCGkXRXxXNeJhbnioz1Q
# 8971   Bd_fzgkfRFc3CgoMydfA6A  mvC-x4kQcwtYM0H3NwHU4g  dOgvND5x_MKMBkqI3GvZXA
# 11806  LNYCZqo_np2lnZqgdWxwrw  Y65389adju10fYZRxnuglw  eUVH2Vs_sHApAKSV4iT2FQ
# 6510   We167JgNnAFM-fR2XcLCSQ  DVv8PrblNGpTtrsSeIclpA  IT8amJTTW64XAre4ilKcjg
# 2762   sEVkMMgu0SwfBRBww4cs-Q  6NSLLVxKY7n6aAXN3bvvZg  Mx8jCUdhaNbMgx_04DWHdA
# 5004   3guTkgVY9qLtWijNHN6gag  7P_niUmr1Vzatr3vOeEc1w  JqBtQ1bSynPHE9gbyuSSvA
# ...

# %% [markdown]
# #### Extract all noun-adjective pairs

# %%
nlp = spacy.load('en_core_web_sm')
noun_adj_pairs = []

for i in random50['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((str(token),str(doc[j])))
              break
noun_adj_pairs
# Out:
# [('Falafels', 'empty'),
#  ('sign', 'half'),
#  ('Chicken', 'half'),
#  ('Shwarma(for', 'half'),
#  ('daughter', 'half'),
#  ('Falafel', 'half'),
#  ('platters', 'half'),
#  ('rice', 'half'),
#  ('salad', 'bland'),
#  ('food', 'bland'),
#  ('presentation', 'bland'),
#  ('food', 'bland'),
#  ('car', 'bland'),
#  ('rice', 'only'),
#  ('falafels', 'only'),
#  ('hummus', 'only'),
#  ('#blandasfuck', 'only'),
#  ('thing', 'pissed'),
#  ('hint', 'pissed'),
#  ('flavor', 'pissed'),
#  ('tzatziki', 'pissed'),
#  ('sauce', 'pissed'),
#  ('people', 'ready'),
#  ('store', 'ready'),
#  ('food', 'ready'),
#  ('system', 'ready'),
#  ('food', 'ready'),
#  ('min', 'other'),
#  ('people', 'sorry'),
#  ('food', 'sorry'),
#  ('person', 'sorry'),
#  ('order', 'sorry'),
#  ('order', 'sorry'),
#  ('food', 'only'),
#  ('order', 'only'),
#  ('people', 'unimpressed'),
#  ('store', 'unimpressed'),
#  ('orders', 'unimpressed'),
#  ('shit', 'Japanese'),
#  ('Nasty', 'Japanese'),
#  ('place', 'Japanese'),
# ...

# %% [markdown]
# #### Find the top 10 most frequent noun-adjective pairs

# %%
counter=collections.Counter(noun_adj_pairs)
print(counter.most_common(10))
# Out:
# [(('food', 'ready'), 4), (('reservation', 'original'), 4), (('food', 'above'), 4), (('fries', 'great'), 4), (('place', 'good'), 3), (('minutes', 'black'), 3), (('hair', 'lighter'), 3), (('chicken', 'green'), 3), (('Chicken', 'delicious'), 3), (('people', 'other'), 3)]

# %% [markdown]
# ## 2 star ratings
# #### Randomly select 20 reviews from different businesses with rating 2

# %%
# Filter reviews with 2 star and store in a dataframe
twoStar = data[data['stars']==2]

# Group by business ID and sample a random 2-star review from each group (1 per business)
grouped = twoStar.groupby('business_id').sample(n=1)

# Randomly select 20 reviews of rating 2 (one from each business)
random20 = grouped.sample(n=20)

# %%
nlp = spacy.load('en_core_web_sm')
noun_adj_pairs = []

for i in random20['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((str(token),str(doc[j])))
              break
noun_adj_pairs
# Out:
# [('place', 'okay'),
#  ('food', 'okay'),
#  ('HK', 'fast'),
#  ('food', 'first'),
#  ('Rest', 'first'),
#  ('time', 'worst'),
#  ('time', 'worst'),
#  ('service', 'empty'),
#  ('mins', 'empty'),
#  ('one', 'empty'),
#  ('party', 'empty'),
#  ('tables', 'lemon'),
#  ('table', 'lemon'),
#  ('Ordered', 'lemon'),
#  ('food', 'lemon'),
#  ('drinks', 'lemon'),
#  ('tea', 'sweet'),
#  ('sugar', 'sweet'),
#  ('server', 'same'),
#  ('attitude', 'same'),
#  ('person', 'same'),
#  ('drink', 'same'),
#  ('mins', 'same'),
#  ('drink', 'same'),
#  ('min', 'same'),
#  ('straw', 'same'),
#  ('lipstick', 'same'),
#  ('colour', 'same'),
#  ('cup', 'sweet'),
#  ('course', 'sweet'),
#  ('service', 'Chinese'),
#  ('food', 'same'),
#  ('rest', 'same'),
#  ('cup', 'same'),
#  ('couple', 'great'),
#  ('weeks', 'great'),
#  ('Food', 'great'),
#  ('Truck', 'great'),
#  ('Fridays', 'great'),
#  ('catfish', 'great'),
#  ('poboy', 'great'),
#  ('sandwich', 'great'),
#  ('catfish', 'great'),
# ...

# %%
counter=collections.Counter(noun_adj_pairs)
print(counter.most_common(10))
# Out:
# [(('time', 'worst'), 2), (('drink', 'same'), 2), (('catfish', 'great'), 2), (('pieces', 'same'), 2), (('progress', 'great'), 2), (('min', 'great'), 2), (('bed', 'uncomfortable'), 2), (('girl', 'front'), 2), (('towels', 'Next'), 2), (('bath', 'Next'), 2)]

# %% [markdown]
# ## 3 star ratings
# #### Randomly select 20 reviews from different businesses with rating 3

# %%
# Filter reviews with 3 star and store in a dataframe
threeStar = data[data['stars']==3]

# Group by business ID and sample a random 3-star review from each group (1 per business)
grouped = threeStar.groupby('business_id').sample(n=1)

# Randomly select 20 reviews of rating 3 (one from each business)
random20 = grouped.sample(n=20)

# %%
nlp = spacy.load('en_core_web_sm')
noun_adj_pairs = []

for i in random20['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((str(token),str(doc[j])))
              break
noun_adj_pairs
# Out:
# [('transmission', 'nice'),
#  ('gasket', 'nice'),
#  ('oil', 'nice'),
#  ('home', 'nice'),
#  ('TJ', 'nice'),
#  ('thing', 'second'),
#  ('car', 'second'),
#  ('shifts', 'second'),
#  ('gear', 'next'),
#  ('TJ', 'next'),
#  ('day', 'following'),
#  ('Capriotti', 'first'),
#  ('time', 'cold'),
#  ('movies', 'cold'),
#  ('Red', 'cold'),
#  ('Rock', 'cold'),
#  ('Casino', 'cold'),
#  ('place', 'cold'),
#  ('sandwiches', 'hot'),
#  ('specials', 'hot'),
#  ('Capastrami', 'hot'),
#  ('cold', 'hot'),
#  ('slaw', 'hot'),
#  ('pastrami', 'Swiss'),
#  ('cheese', 'Russian'),
#  ('dressing', 'ok'),
#  ('CAPASTRAMI', 'ok'),
#  ('bread', 'soft'),
#  ('thing', 'bad'),
#  ('thing', 'cold'),
#  ('proportion', 'cold'),
#  ('slaw', 'half'),
#  ('pastrami', 'cold'),
#  ('cheese', 'cold'),
#  ('proportion', 'cold'),
#  ('pastrami', 'cold'),
#  ('slaw', 'other'),
#  ('pastrami', 'other'),
#  ('sandwich', 'other'),
#  ('proportion', 'other'),
#  ('sandwich', 'other'),
#  ('pastrami', 'other'),
# ...

# %%
counter=collections.Counter(noun_adj_pairs)
print(counter.most_common(10))
# Out:
# [(('shrimp', 'good'), 3), (('proportion', 'cold'), 2), (('pastrami', 'cold'), 2), (('pastrami', 'other'), 2), (('sandwich', 'other'), 2), (('sandwich', 'bad'), 2), (('food', 'decent'), 2), (('service', 'decent'), 2), (('cherry', 'friendly'), 2), (('syrup', 'friendly'), 2)]

# %% [markdown]
# ## 4 star ratings
# #### Randomly select 20 reviews from different businesses with rating 4

# %%
# Filter reviews with 4 star and store in a dataframe
fourStar = data[data['stars']==4]

# Group by business ID and sample a random 4-star review from each group (1 per business)
grouped = fourStar.groupby('business_id').sample(n=1)

# Randomly select 20 reviews of rating 4 (one from each business)
random20 = grouped.sample(n=20)

# %% [markdown]
# #### Extract all noun-adjective pairs

# %%
nlp = spacy.load('en_core_web_sm')
noun_adj_pairs = []

for i in random20['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((str(token),str(doc[j])))
              break
noun_adj_pairs
# Out:
# [('service', 'friendly'),
#  ('decor', 'Japanese'),
#  ('music', 'moist'),
#  ('environment', 'moist'),
#  ('day', 'awesome'),
#  ('food', 'awesome'),
#  ('bar', 'large'),
#  ('Kirin', 'generous'),
#  ('beers', 'generous'),
#  ('Sushi', 'generous'),
#  ('sashimi', 'generous'),
#  ('portions', 'nice'),
#  ('fish', 'nice'),
#  ('Orange', 'nice'),
#  ('chicken', 'nice'),
#  ('Pizza', 'great'),
#  ('subs', 'great'),
#  ('smells', 'little'),
#  ('pasta', 'little'),
#  ('dishes', 'little'),
#  ('sauce', 'little'),
#  ('taste', 'great'),
#  ('place', 'great'),
#  ('service', 'great'),
#  ('hotel', 'great'),
#  ('flaws', 'free'),
#  ('drinks', 'great'),
#  ('drinks', 'special'),
#  ('manager', 'special'),
#  ('everyday', 'amazing'),
#  ('room', 'amazing'),
#  ('floor', 'amazing'),
#  ('view', 'amazing'),
#  ('room', 'worth'),
#  ('win', 'worth'),
#  ('win', 'worth'),
#  ('restaurant', 'worth'),
#  ('bar', 'worth'),
#  ('street', 'worth'),
#  ('locker', 'worth'),
#  ('room', 'worth'),
# ...

# %% [markdown]
# #### Find the top 10 most frequent noun-adjective pairs

# %%
counter=collections.Counter(noun_adj_pairs)
print(counter.most_common(10))
# Out:
# [(('place', 'great'), 2), (('service', 'great'), 2), (('room', 'worth'), 2), (('win', 'worth'), 2), (('kids', 'best'), 2), (('space', 'western'), 2), (('food', 'strong'), 2), (('hardware', 'willing'), 2), (('work', 'friendly'), 2), (('tech', 'free'), 2)]

# %% [markdown]
# ## 5 star ratings
# #### Randomly select 20 reviews from different businesses with rating 5

# %%
# Filter reviews with 5 star and store in a dataframe
fiveStar = data[data['stars']==5]

# Group by business ID and sample a random 5-star review from each group (1 per business)
grouped = fiveStar.groupby('business_id').sample(n=1)

# Randomly select 20 reviews of rating 5 (one from each business)
random20 = grouped.sample(n=20)

# %% [markdown]
# #### Extract all noun-adjective pairs

# %%
nlp = spacy.load('en_core_web_sm')
noun_adj_pairs = []

for i in random20['text']:
  doc = nlp(i)
  for i,token in enumerate(doc):
      if token.pos_ not in ('NOUN','PROPN'):
          continue
      for j in range(i+1,len(doc)):
          if doc[j].pos_ == 'ADJ':
              noun_adj_pairs.append((str(token),str(doc[j])))
              break
noun_adj_pairs
# Out:
# [('VooDoo', 'awesome'),
#  ('Taco', 'awesome'),
#  ('Aloha', 'awesome'),
#  ('Burger', 'awesome'),
#  ('trip', 'memorable'),
#  ('Phoenix', 'memorable'),
#  ('place', 'good'),
#  ('burger', 'relaxed'),
#  ('atmosphere', 'relaxed'),
#  ('BR', 'Great'),
#  ('condo', 'Great'),
#  ('experience', 'little'),
#  ('Bathrooms', 'modern'),
#  ('rate', 'full'),
#  ('king', 'full'),
#  ('beds', 'full'),
#  ('bath', 'full'),
#  ('area', 'full'),
#  ('pullout', 'full'),
#  ('kitchen', 'Nice'),
#  ('stars', 'Nice'),
#  ('value', 'Nice'),
#  ('pools', 'small'),
#  ('kids', 'old'),
#  ('day', 'old'),
#  ('homebase', 'old'),
#  ('strip', 'old'),
#  ('couples', 'old'),
#  ('kids', 'old'),
#  ('blast', 'old'),
#  ('TV', 'old'),
#  ('living', 'old'),
#  ('room', 'old'),
#  ('HD', 'old'),
#  ('sushi', 'best'),
#  ('Toronto', 'best'),
#  ('part', 'amazing'),
#  ('u', 'amazing'),
#  ('avacado', 'amazing'),
#  ('rolls', 'amazing'),
#  ('shrimp', 'amazing'),
#  ('tempura', 'amazing'),
#  ('places', 'blan'),
# ...

# %% [markdown]
# #### Find the top 10 most frequent noun-adjective pairs

# %%
counter=collections.Counter(noun_adj_pairs)
print(counter.most_common(10))
# Out:
# [(('bacon', 'heavy'), 3), (('kids', 'old'), 2), (('way', 'spicy'), 2), (('sauce', 'green'), 2), (('Gnocchi', 'green'), 2), (('food', 'delicious'), 2), (('beef', 'heavy'), 2), (('Ed', 'great'), 2), (('VooDoo', 'awesome'), 1), (('Taco', 'awesome'), 1)]
